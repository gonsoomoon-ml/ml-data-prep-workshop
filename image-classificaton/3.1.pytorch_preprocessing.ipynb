# %% [markdown]
# # [모듈 4.1] Pytorch 를 위한 이미지 전처리
# Download | Structure | **Preprocessing (PyTorch)** | Train Model (PyTorch) (4단계 중의 3/4)

# %% [markdown]
# ### [알림] <font coler="red"> conda_ptroech_p36 커널 </font> 과 함께 사용해야 합니다.
#
# * 이 노트북은 `1.1.download_data` 및 `1.2.structuring_data`로 시작하는 일련의 노트북의 일부입니다. 여기부터는 TensorFlow에 대한 SageMaker의 지원에 중점을 둘 것입니다. 이 시리즈의 다음 노트북은 '4.2.pytorch_training'입니다.

# %% [markdown]
# # 노트북 요약
# ---

# %% [markdown]
# - 이 노트북에서는 PyTorch로 훈련하기 위한 크기 조정 및 데이터 증강 변환을 생성합니다.
# - 또한 SageMaker를 사용한 교육을 위해 데이터 세트를 S3에 업로드합니다.

# %% [markdown]
# # 0. 환경 설정
# ___
# Pytorch를 1.6.0로 업데이트하고 torchvision 을 설치합니다.

# %% [markdown]
# ### Update the SageMaker Python SDK and PyTorch

# %%
import sys
original_pytorch_version = !conda list | grep -E "torch\s" | awk '{print $2}'
# !{sys.executable} -m pip install -q "torch==1.6.0" "torchvision" "tqdm"
# Out:
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# fastai 1.0.61 requires nvidia-ml-py3, which is not installed.

# %%
import uuid
import boto3
import torch
import shutil
import pickle
import pathlib
import sagemaker
import numpy as np
from tqdm import tqdm
import torchvision as tv
import matplotlib.pyplot as plt

# %%
print(f"pytorch   updated  {original_pytorch_version[0]} -> {torch.__version__}")
# Out:
# pytorch   updated  1.4.0 -> 1.6.0

# %% [markdown]
# # 1. 크기 조정 변환 정의
#
# - 훈련을 위해 GPU로 이동하기 전에 모든 이미지 데이터의 길이, 너비 및 채널 차원이 동일해야 합니다.
#     - 일반적으로 알고리즘은 정사각형 형식을 사용하므로 길이와 너비가 동일하고, 미리 만들어진 많은 데이터 세트에는 이미지가 정사각형으로 잘 잘려져 있습니다.
#
#
# - 그러나 현업에서는 실제 데이터 세트는 다양한 차원과 비율의 이미지로 존재합니다. 훈련을 위해 데이터 세트를 준비하려면 이미지가 정사각형이 아닌 경우 크기를 조정하고 잘라야 합니다.
#
#
#
# - 이미지가 찌그러지거나 늘어나는 것을 방지하려면  <font color="red">이미지를 정사각형으로 *그리고* 이미지의 중요한 개체가 잘리지 않도록 해야 합니다.</font>
#     - 불행히도 각 정사각형이 최적인지 확인하는 쉬운 방법은 없으므로 일반적으로 대부분에 잘 작동하는 정사각형을 선택하고 자릅니다.

# %%
resize = tv.transforms.Compose(
    [tv.transforms.Resize(224), tv.transforms.CenterCrop(224), tv.transforms.ToTensor()]
)

# %% [markdown]
# ## 토치비젼을 통한 훈련 데이터 세트 셍성

# %%
# 정상 데이터 세트
sample = tv.datasets.ImageFolder(root="data_structured/train", transform=tv.transforms.ToTensor())
# 리사이즈된 데이터 세트
sample_resized = tv.datasets.ImageFolder(root="data_structured/train", transform=resize)

# %% [markdown]
# 첫번째 레코드의 이미지 Shape 과 레이블 값을 확인 합니다.

# %%
example = iter(sample)
image, label = next(example)
print(f"image shape: {image.shape}, label: {label}")
# Out:
# image shape: torch.Size([3, 427, 640]), label: 0

# %%
sample = iter(sample)
sample_resized = iter(sample_resized)

# %% [markdown]
# 다른 이미지에서 크기 조정 변환을 보려면 아래 셀을 다시 실행하십시오.
# - 반복해서 실행하시면 다른 이미지의 결과가 보입니다.

# %%
fig, ax = plt.subplots(1, 2, figsize=(10, 5))
image = next(iter(sample))[0]
image_resized = next(iter(sample_resized))[0]

ax[0].imshow(image.permute(1, 2, 0))
ax[0].axis("off")
ax[0].set_title(f"Before - {tuple(image.shape)}")
ax[1].imshow(image_resized.permute(1, 2, 0))
ax[1].axis("off")
ax[1].set_title(f"After - {tuple(image_resized.shape)}")
plt.tight_layout()

# %% [markdown]
# <pre>
# </pre>

# %% [markdown]
# # 2. 데이터 증강 정의
# - 훈련을 개선하는 쉬운 방법은 훈련 알고리즘이 더 잘 일반화되도록 이미지를 무작위로 늘리는 것입니다. 선택할 수 있는 증강은 많지만 증강 기능에 더 많이 추가할수록 훈련을 위해 GPU로 이미지를 보내기 전에 더 많은 처리가 필요하다는 점을 명심하십시오.
# - 또한 이미지에 대한 예측을 있는 그대로 생성하기를 원하기 때문에 검증 데이터를 증강할 필요가 없다는 점에 유의하는 것이 중요합니다.

# %%
augment = tv.transforms.Compose(
    [
        # tv.transforms.RandomResizedCrop(224),
        tv.transforms.RandomHorizontalFlip(p=0.5),
        tv.transforms.RandomVerticalFlip(p=0.5),
        tv.transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.2),
        tv.transforms.ToTensor(),
    ]
)

# %%
sample = tv.datasets.ImageFolder(root="data_structured/train", transform=tv.transforms.ToTensor())
sample_augmented = tv.datasets.ImageFolder(root="data_structured/train", transform=augment)

# %%
sample = iter(sample)
sample_augmented = iter(sample_augmented)

# %% [markdown]
# 반복해서 실행하시면 다른 이미지의 결과가 보입니다.

# %%
fig, ax = plt.subplots(1, 2, figsize=(10, 5))
image = next(iter(sample))[0]
image_augmented = next(iter(sample_augmented))[0]

ax[0].imshow(image.permute(1, 2, 0))
ax[0].axis("off")
ax[0].set_title(f"Before - {tuple(image.shape)}")
ax[1].imshow(image_augmented.permute(1, 2, 0))
ax[1].axis("off")
ax[1].set_title(f"After - {tuple(image_augmented.shape)}")
plt.tight_layout()

# %% [markdown]
# <pre>
# </pre>

# %% [markdown]
# # 3. 데이터세트에 변환 (Resize, Augmentation) 적용
# - 훈련 데이터 세트에는 크기 조정 및 증대 기능이 적용되지만 검증 데이터 세트는 훈련에 직접 사용되지 않기 때문에 크기만 조정됩니다.
# - 각 레코드에 변환을 적용하기 위해 `.map()` 메서드를 호출할 때. 그러나 실제로는 아직 이미지를 변환하지 않습니다. 대신 훈련을 위해 GPU로 전송되기 직전에 CPU에 의해 변환이 완전히 적용됩니다. 이것은 모든 이미지가 변환될 때까지 기다릴 필요 없이 빠르게 실험할 수 있기 때문에 좋습니다.
#
#
# - 변환을 무작위로 적용하는 이유가 궁금할 것입니다. 이는 훈련 알고리즘이 에포크의 데이터를 순환하기 때문에 수행됩니다.
#     - 매 에포크마다 이미지를 다시 볼 수 있는 기회가 생기므로 매번 동일한 이미지를 전송하는 대신 무작위 증강을 적용합니다.
#     - 이상적으로는 알고리즘이 매 에포크마다 이미지의 모든 버전을 보도록 하겠지만, 이렇게 하면 훈련 데이터 세트의 크기가 증강 수만큼 확장됩니다. 해당 요인에 따라 데이터 스토리지 및 훈련 시간을 확장하는 것은 크게 가치가 없습니다.

# %%
data_transforms = {
    "train": tv.transforms.Compose(
        [
            tv.transforms.RandomResizedCrop(224),
            tv.transforms.RandomHorizontalFlip(p=0.5),
            tv.transforms.RandomVerticalFlip(p=0.5),
            tv.transforms.ColorJitter(brightness=0.1, contrast=0.1, saturation=0.1, hue=0.1),
            tv.transforms.ToTensor(),
        ]
    ),
    "val": tv.transforms.Compose(
        [tv.transforms.Resize(224), tv.transforms.CenterCrop(224), tv.transforms.ToTensor()]
    ),
}

# %% [markdown]
# ## PyTorch 데이터 세트 및 데이터 로더 생성

# %% [markdown]
# ### Datasets
# - PyTorch의 데이터 세트는 데이터 세트의 모든 데이터를 추적합니다. 즉, 데이터 세트를 찾을 위치(해당 경로), 해당 데이터가 속한 클래스 및 가져오는 변환을 추적합니다.
# - 이 경우 PyTorch의 편리한 `ImageFolder`를 사용하여 이전 가이드에서 생성한 디렉토리 구조에서 데이터 세트를 쉽게 생성할 것입니다.

# %%
data_dir = pathlib.Path("./data_structured")
splits = ["train", "val"]

datasets = {}
for s in splits:
    datasets[s] = tv.datasets.ImageFolder(root=data_dir / s, transform=data_transforms[s])

# %% [markdown]
# ### 데이터 로더
# 데이터 로더는 이미지가 훈련을 위해 CPU와 GPU로 전송되는 방식을 구성합니다. 다음과 같은 중요한 하이퍼 매개변수가 포함됩니다.
# * **batch_size**: 데이터 로더에게 역전파를 위해 훈련 알고리즘에 한 번에 보낼 이미지 수를 알려줍니다. 따라서 SGD와 같은 최적화 프로그램에 대해 한 에포크에서 발생하는 그래디언트 업데이트 수를 제어합니다.
# * **shuffle**: 학습 데이터의 순서를 무작위로 지정합니다.
# * **num_workers**: 훈련을 위해 GPU로 보내기 전에 이미지를 로드하고 변환하려는 병렬 프로세스의 수를 정의합니다. 따라서 더 많은 작업자를 추가하면 훈련 속도가 빨라집니다. 그러나 작업자가 너무 많으면 모든 작업자를 관리해야 하는 오버헤드로 인해 훈련 속도가 느려집니다. 또한 각 작업자는 상당한 양의 RAM(batch_size에 따라 다름)을 소비하며 훈련에 사용되는 EC2 인스턴스에서 사용 가능한 CPU 코어보다 많은 작업자를 가질 수 없습니다.

# %%
batch_size = 4
shuffle = True
num_workers = 4

dataloaders = {}
for s in splits:
    dataloaders[s] = torch.utils.data.DataLoader(
        datasets[s], batch_size=batch_size, shuffle=shuffle, num_workers=num_workers
    )

# %% [markdown]
# ## 변환 시각화
# ___
# 모든 것이 제대로 작동하는지 확인하기 위해 몇 가지 이미지에 변형을 적용하고 확인을 합니다. 새로운 이미지 배치를 보려면 셀을 다시 실행하기만 하면 됩니다.

# %%
rows = 3
cols = batch_size
fig, axs = plt.subplots(rows, cols, figsize=(10, 7))

for row in range(rows):
    batch = next(iter(dataloaders["train"]))
    images, labels = batch
    for col, image in enumerate(images):
        ax = axs[row, col]
        ax.imshow(image.permute(2, 1, 0))
        ax.axis("off")

plt.tight_layout()

# %% [markdown]
# <pre>
# </pre>

# %% [markdown]
# 데이터 세트와 데이터 로더가 정의되었으므로 이제 모델에 대한 훈련 아키텍처를 정의할 준비가 되었습니다.

# %% [markdown]
# # 4. S3 에 리사이징된 파일 업로드
# ___

# %% [markdown]
# ## 이미지를 리사이징을 하고 디스크에 저장
# - data_structured 의 train, val, test 데이터를 리사징하여 data_resized 폴더에 저장

# %%
data_dir = pathlib.Path("./data_structured")
splits = ["train", "val", "test"]

datasets = {}
for s in splits:
    datasets[s] = tv.datasets.ImageFolder(
        root=data_dir / s,
        transform=tv.transforms.Compose([tv.transforms.Resize(224), tv.transforms.ToTensor()]),
    )

# %%
resized_path = pathlib.Path("./data_resized")
resized_path.mkdir(exist_ok=True)
for s in splits:
    split_path = resized_path / s
    split_path.mkdir(exist_ok=True)
    for idx, (img_tensor, label) in enumerate(tqdm(datasets[s])):
        label_path = split_path / f"{label:02}"
        label_path.mkdir(exist_ok=True)
        filename = datasets[s].imgs[idx][0].split("/")[-1]
        tv.utils.save_image(img_tensor, label_path / filename)
# Out:
# 100%|██████████| 2200/2200 [00:28<00:00, 78.06it/s]
# 100%|██████████| 275/275 [00:03<00:00, 75.99it/s]
# 100%|██████████| 275/275 [00:03<00:00, 79.06it/s]

# %% [markdown]
# ### 리사이즈된 이미지를 S3에 업로딩
# - 약 3분 소요 됩니다.

# %%
import sagemaker
bucket_name = sagemaker.Session().default_bucket()
print(bucket_name)
# Out:
# sagemaker-ap-northeast-2-057716757052

# %%
pytorch_prefix = 'data_prep_workshop/pytorch'

# %%
s3_uploader = sagemaker.s3.S3Uploader()

train_s3_uri = f's3://{bucket_name}/{pytorch_prefix}/data/train'    
data_path = (resized_path / 'train').as_posix()
train_pytorch_s3_uri = s3_uploader.upload(
    local_path=data_path, desired_s3_uri=train_s3_uri
)
print("train_pytorch_s3_uri: \n", train_pytorch_s3_uri)
# Out:
# train_pytorch_s3_uri:
#  s3://sagemaker-ap-northeast-2-057716757052/data_prep_workshop/pytorch/data/train

# %%
s3_uploader = sagemaker.s3.S3Uploader()

val_s3_uri = f's3://{bucket_name}/{pytorch_prefix}/data/val'    
data_path = (resized_path / 'val').as_posix()
val_pytorch_s3_uri = s3_uploader.upload(
    local_path=data_path, desired_s3_uri=val_s3_uri
)
print("val_pytorch_s3_uri: \n", val_pytorch_s3_uri)
# Out:
# val_pytorch_s3_uri:
#  s3://sagemaker-ap-northeast-2-057716757052/data_prep_workshop/pytorch/data/val

# %% [markdown]
# <pre>
# </pre>

# %% [markdown]
# ## 다음 노트북에서 사용할 변수 저장
# - 아래는 다음 노트북에서 변수를 사용하기 위해 저장 합니다.

# %%
# %store train_pytorch_s3_uri
# %store val_pytorch_s3_uri
# %store bucket_name
# Out:
# Stored 'train_pytorch_s3_uri' (str)
# Stored 'val_pytorch_s3_uri' (str)
# Stored 'bucket_name' (str)

# %% [markdown]
# ## 데이터 확인

# %%
! aws s3 ls {train_pytorch_s3_uri} --recursive
! aws s3 ls {val_pytorch_s3_uri} --recursive
# Out:
# 2022-01-04 02:15:22      18974 data_prep_workshop/pytorch/data/train/00/000000000502.jpg
# 2022-01-04 02:15:15      26400 data_prep_workshop/pytorch/data/train/00/000000003481.jpg
# 2022-01-04 02:15:15      10145 data_prep_workshop/pytorch/data/train/00/000000006437.jpg
# 2022-01-04 02:15:19      16848 data_prep_workshop/pytorch/data/train/00/000000013843.jpg
# 2022-01-04 02:15:14      16193 data_prep_workshop/pytorch/data/train/00/000000015391.jpg
# 2022-01-04 02:15:15      16596 data_prep_workshop/pytorch/data/train/00/000000020136.jpg
# 2022-01-04 02:15:14      11540 data_prep_workshop/pytorch/data/train/00/000000020247.jpg
# 2021-12-28 07:37:33      10821 data_prep_workshop/pytorch/data/train/00/000000020972.jpg
# 2022-01-04 02:15:17       9045 data_prep_workshop/pytorch/data/train/00/000000021963.jpg
# 2022-01-04 02:15:23      17105 data_prep_workshop/pytorch/data/train/00/000000024351.jpg
# 2022-01-04 02:15:16      17147 data_prep_workshop/pytorch/data/train/00/000000031375.jpg
# 2022-01-04 02:15:23      18709 data_prep_workshop/pytorch/data/train/00/000000041226.jpg
# 2022-01-04 02:15:21      15490 data_prep_workshop/pytorch/data/train/00/000000042296.jpg
# 2022-01-04 02:15:23      19126 data_prep_workshop/pytorch/data/train/00/000000046211.jpg
# 2022-01-04 02:15:24      25187 data_prep_workshop/pytorch/data/train/00/000000046612.jpg
# 2022-01-04 02:15:17      18541 data_prep_workshop/pytorch/data/train/00/000000047936.jpg
# 2022-01-04 02:15:22      10815 data_prep_workshop/pytorch/data/train/00/000000051894.jpg
# 2022-01-04 02:15:20      30592 data_prep_workshop/pytorch/data/train/00/000000052938.jpg
# 2022-01-04 02:15:17      17975 data_prep_workshop/pytorch/data/train/00/000000054262.jpg
# 2022-01-04 02:15:17      24660 data_prep_workshop/pytorch/data/train/00/000000059079.jpg
# 2022-01-04 02:15:21      19928 data_prep_workshop/pytorch/data/train/00/000000060688.jpg
# 2022-01-04 02:15:18      26252 data_prep_workshop/pytorch/data/train/00/000000062540.jpg
# 2022-01-04 02:15:22      15693 data_prep_workshop/pytorch/data/train/00/000000063486.jpg
# 2022-01-04 02:15:19      17464 data_prep_workshop/pytorch/data/train/00/000000067015.jpg
# 2022-01-04 02:15:14      12950 data_prep_workshop/pytorch/data/train/00/000000078112.jpg
# 2022-01-04 02:15:14       9581 data_prep_workshop/pytorch/data/train/00/000000079104.jpg
# 2022-01-04 02:15:23      10511 data_prep_workshop/pytorch/data/train/00/000000079394.jpg
# 2022-01-04 02:15:18       6303 data_prep_workshop/pytorch/data/train/00/000000081081.jpg
# 2021-12-28 07:37:33      11767 data_prep_workshop/pytorch/data/train/00/000000084158.jpg
# 2022-01-04 02:15:16      13759 data_prep_workshop/pytorch/data/train/00/000000085670.jpg
# 2022-01-04 02:15:15      15977 data_prep_workshop/pytorch/data/train/00/000000089254.jpg
# 2022-01-04 02:15:17      14409 data_prep_workshop/pytorch/data/train/00/000000091546.jpg
# 2022-01-04 02:15:22      17113 data_prep_workshop/pytorch/data/train/00/000000091858.jpg
# 2022-01-04 02:15:19      12350 data_prep_workshop/pytorch/data/train/00/000000094926.jpg
# 2022-01-04 02:15:19      19448 data_prep_workshop/pytorch/data/train/00/000000096034.jpg
# 2022-01-04 02:15:23      21684 data_prep_workshop/pytorch/data/train/00/000000098197.jpg
# 2022-01-04 02:15:17      25528 data_prep_workshop/pytorch/data/train/00/000000105134.jpg
# 2022-01-04 02:15:24      17558 data_prep_workshop/pytorch/data/train/00/000000105719.jpg
# 2022-01-04 02:15:18      22900 data_prep_workshop/pytorch/data/train/00/000000115331.jpg
# 2022-01-04 02:15:15      15000 data_prep_workshop/pytorch/data/train/00/000000118342.jpg
# 2022-01-04 02:15:15      13467 data_prep_workshop/pytorch/data/train/00/000000118748.jpg
# 2022-01-04 02:15:25      12629 data_prep_workshop/pytorch/data/train/00/000000121876.jpg
# 2022-01-04 02:15:23      15915 data_prep_workshop/pytorch/data/train/00/000000123891.jpg
# 2022-01-04 02:15:22      20514 data_prep_workshop/pytorch/data/train/00/000000125412.jpg
# 2022-01-04 02:15:24      16013 data_prep_workshop/pytorch/data/train/00/000000127955.jpg
# 2022-01-04 02:15:19      16867 data_prep_workshop/pytorch/data/train/00/000000130037.jpg
# 2022-01-04 02:15:22      22924 data_prep_workshop/pytorch/data/train/00/000000130966.jpg
# 2022-01-04 02:15:17      25103 data_prep_workshop/pytorch/data/train/00/000000134846.jpg
# 2022-01-04 02:15:24      20827 data_prep_workshop/pytorch/data/train/00/000000140289.jpg
# 2022-01-04 02:15:15      15948 data_prep_workshop/pytorch/data/train/00/000000141468.jpg
# 2022-01-04 02:15:22      18494 data_prep_workshop/pytorch/data/train/00/000000149338.jpg
# 2022-01-04 02:15:15      14908 data_prep_workshop/pytorch/data/train/00/000000149583.jpg
# 2022-01-04 02:15:23      14969 data_prep_workshop/pytorch/data/train/00/000000149657.jpg
# 2022-01-04 02:15:17      25887 data_prep_workshop/pytorch/data/train/00/000000155884.jpg
# 2022-01-04 02:15:16      10910 data_prep_workshop/pytorch/data/train/00/000000158326.jpg
# 2022-01-04 02:15:19      19460 data_prep_workshop/pytorch/data/train/00/000000163306.jpg
# 2022-01-04 02:15:16      13086 data_prep_workshop/pytorch/data/train/00/000000169313.jpg
# 2022-01-04 02:15:15      15640 data_prep_workshop/pytorch/data/train/00/000000170730.jpg
# 2022-01-04 02:15:16      10223 data_prep_workshop/pytorch/data/train/00/000000173033.jpg
# 2022-01-04 02:15:21      19866 data_prep_workshop/pytorch/data/train/00/000000174457.jpg
# 2022-01-04 02:15:20      20003 data_prep_workshop/pytorch/data/train/00/000000175210.jpg
# 2022-01-04 02:15:14      16369 data_prep_workshop/pytorch/data/train/00/000000183949.jpg
# 2021-12-28 07:37:34      20732 data_prep_workshop/pytorch/data/train/00/000000186124.jpg
# 2022-01-04 02:15:20      15138 data_prep_workshop/pytorch/data/train/00/000000189095.jpg
# 2022-01-04 02:15:20      17569 data_prep_workshop/pytorch/data/train/00/000000189993.jpg
# 2021-12-28 07:37:33      14525 data_prep_workshop/pytorch/data/train/00/000000193435.jpg
# 2021-12-28 07:37:33      12004 data_prep_workshop/pytorch/data/train/00/000000194352.jpg
# 2021-12-28 07:37:33      14757 data_prep_workshop/pytorch/data/train/00/000000199943.jpg
# 2022-01-04 02:15:16      12872 data_prep_workshop/pytorch/data/train/00/000000201241.jpg
# 2022-01-04 02:15:20      16174 data_prep_workshop/pytorch/data/train/00/000000202966.jpg
# 2022-01-04 02:15:20      17162 data_prep_workshop/pytorch/data/train/00/000000203635.jpg
# 2022-01-04 02:15:19      11415 data_prep_workshop/pytorch/data/train/00/000000204381.jpg
# 2022-01-04 02:15:22      12958 data_prep_workshop/pytorch/data/train/00/000000206809.jpg
# 2022-01-04 02:15:16      18439 data_prep_workshop/pytorch/data/train/00/000000206927.jpg
# 2022-01-04 02:15:16      15664 data_prep_workshop/pytorch/data/train/00/000000211560.jpg
# 2022-01-04 02:15:16      15291 data_prep_workshop/pytorch/data/train/00/000000212203.jpg
# 2022-01-04 02:15:24      15646 data_prep_workshop/pytorch/data/train/00/000000215939.jpg
# 2022-01-04 02:15:16      16651 data_prep_workshop/pytorch/data/train/00/000000216063.jpg
# 2022-01-04 02:15:18      14949 data_prep_workshop/pytorch/data/train/00/000000216371.jpg
# 2022-01-04 02:15:15      15642 data_prep_workshop/pytorch/data/train/00/000000218215.jpg
# 2022-01-04 02:15:15      12230 data_prep_workshop/pytorch/data/train/00/000000218255.jpg
# 2022-01-04 02:15:19      15177 data_prep_workshop/pytorch/data/train/00/000000224193.jpg
# 2022-01-04 02:15:25      21370 data_prep_workshop/pytorch/data/train/00/000000224878.jpg
# 2022-01-04 02:15:21      15625 data_prep_workshop/pytorch/data/train/00/000000226585.jpg
# 2022-01-04 02:15:21      10531 data_prep_workshop/pytorch/data/train/00/000000230428.jpg
# 2022-01-04 02:15:17      13429 data_prep_workshop/pytorch/data/train/00/000000233926.jpg
# 2022-01-04 02:15:16      19497 data_prep_workshop/pytorch/data/train/00/000000233948.jpg
# 2022-01-04 02:15:19      14864 data_prep_workshop/pytorch/data/train/00/000000238839.jpg
# 2022-01-04 02:15:22      17129 data_prep_workshop/pytorch/data/train/00/000000239706.jpg
# 2021-12-28 07:37:33      18056 data_prep_workshop/pytorch/data/train/00/000000245135.jpg
# 2022-01-04 02:15:23      14231 data_prep_workshop/pytorch/data/train/00/000000249346.jpg
# 2022-01-04 02:15:17      18880 data_prep_workshop/pytorch/data/train/00/000000252382.jpg
# 2022-01-04 02:15:24      17395 data_prep_workshop/pytorch/data/train/00/000000253763.jpg
# 2022-01-04 02:15:16      13419 data_prep_workshop/pytorch/data/train/00/000000254479.jpg
# 2022-01-04 02:15:19      18541 data_prep_workshop/pytorch/data/train/00/000000255575.jpg
# 2022-01-04 02:15:19      17975 data_prep_workshop/pytorch/data/train/00/000000256276.jpg
# 2022-01-04 02:15:22      12449 data_prep_workshop/pytorch/data/train/00/000000261043.jpg
# 2022-01-04 02:15:20      14573 data_prep_workshop/pytorch/data/train/00/000000262933.jpg
# 2022-01-04 02:15:15      16085 data_prep_workshop/pytorch/data/train/00/000000267898.jpg
# 2022-01-04 02:15:20      15721 data_prep_workshop/pytorch/data/train/00/000000269380.jpg
# 2022-01-04 02:15:18      18864 data_prep_workshop/pytorch/data/train/00/000000271568.jpg
# 2022-01-04 02:15:17      16675 data_prep_workshop/pytorch/data/train/00/000000274463.jpg
# 2022-01-04 02:15:22      12206 data_prep_workshop/pytorch/data/train/00/000000278287.jpg
# 2022-01-04 02:15:25      10758 data_prep_workshop/pytorch/data/train/00/000000282419.jpg
# 2022-01-04 02:15:24      14526 data_prep_workshop/pytorch/data/train/00/000000283849.jpg
# 2022-01-04 02:15:23      15779 data_prep_workshop/pytorch/data/train/00/000000285908.jpg
# 2022-01-04 02:15:18      32852 data_prep_workshop/pytorch/data/train/00/000000285929.jpg
# 2022-01-04 02:15:22      13525 data_prep_workshop/pytorch/data/train/00/000000286745.jpg
# 2022-01-04 02:15:24      10729 data_prep_workshop/pytorch/data/train/00/000000286764.jpg
# 2022-01-04 02:15:16      12431 data_prep_workshop/pytorch/data/train/00/000000291114.jpg
# 2022-01-04 02:15:18      16656 data_prep_workshop/pytorch/data/train/00/000000292435.jpg
# 2021-12-28 07:37:33      13123 data_prep_workshop/pytorch/data/train/00/000000292982.jpg
# 2022-01-04 02:15:24       7579 data_prep_workshop/pytorch/data/train/00/000000295370.jpg
# 2022-01-04 02:15:21      14587 data_prep_workshop/pytorch/data/train/00/000000300123.jpg
# 2022-01-04 02:15:19      10949 data_prep_workshop/pytorch/data/train/00/000000301747.jpg
# 2022-01-04 02:15:22      10884 data_prep_workshop/pytorch/data/train/00/000000304220.jpg
# 2021-12-28 07:37:33      17625 data_prep_workshop/pytorch/data/train/00/000000306222.jpg
# 2022-01-04 02:15:18      17370 data_prep_workshop/pytorch/data/train/00/000000309181.jpg
# 2022-01-04 02:15:22      22194 data_prep_workshop/pytorch/data/train/00/000000313412.jpg
# 2022-01-04 02:15:21      13841 data_prep_workshop/pytorch/data/train/00/000000315622.jpg
# 2022-01-04 02:15:17      14234 data_prep_workshop/pytorch/data/train/00/000000317428.jpg
# 2022-01-04 02:15:16      18132 data_prep_workshop/pytorch/data/train/00/000000322392.jpg
# 2022-01-04 02:15:17      15444 data_prep_workshop/pytorch/data/train/00/000000322553.jpg
# 2022-01-04 02:15:18      18376 data_prep_workshop/pytorch/data/train/00/000000329457.jpg
# 2021-12-28 07:37:33      19111 data_prep_workshop/pytorch/data/train/00/000000334194.jpg
# 2022-01-04 02:15:22      17070 data_prep_workshop/pytorch/data/train/00/000000340612.jpg
# 2022-01-04 02:15:23      17554 data_prep_workshop/pytorch/data/train/00/000000340698.jpg
# 2022-01-04 02:15:21      15935 data_prep_workshop/pytorch/data/train/00/000000341511.jpg
# 2022-01-04 02:15:24      18589 data_prep_workshop/pytorch/data/train/00/000000344744.jpg
# 2021-12-28 07:37:33      21995 data_prep_workshop/pytorch/data/train/00/000000348669.jpg
# 2022-01-04 02:15:20      19766 data_prep_workshop/pytorch/data/train/00/000000353306.jpg
# 2022-01-04 02:15:20      14693 data_prep_workshop/pytorch/data/train/00/000000353605.jpg
# 2022-01-04 02:15:16      16285 data_prep_workshop/pytorch/data/train/00/000000359337.jpg
# 2022-01-04 02:15:16      15106 data_prep_workshop/pytorch/data/train/00/000000360367.jpg
# 2022-01-04 02:15:23      12854 data_prep_workshop/pytorch/data/train/00/000000360826.jpg
# 2022-01-04 02:15:19      25170 data_prep_workshop/pytorch/data/train/00/000000361341.jpg
# 2022-01-04 02:15:25      32524 data_prep_workshop/pytorch/data/train/00/000000364040.jpg
# 2022-01-04 02:15:18      16253 data_prep_workshop/pytorch/data/train/00/000000366508.jpg
# 2022-01-04 02:15:18      12845 data_prep_workshop/pytorch/data/train/00/000000375015.jpg
# 2022-01-04 02:15:14      11922 data_prep_workshop/pytorch/data/train/00/000000376443.jpg
# 2022-01-04 02:15:20      16297 data_prep_workshop/pytorch/data/train/00/000000377294.jpg
# 2022-01-04 02:15:16      13870 data_prep_workshop/pytorch/data/train/00/000000382939.jpg
# 2022-01-04 02:15:24      18375 data_prep_workshop/pytorch/data/train/00/000000396194.jpg
# 2022-01-04 02:15:17      13741 data_prep_workshop/pytorch/data/train/00/000000399829.jpg
# 2021-12-28 07:37:33      15673 data_prep_workshop/pytorch/data/train/00/000000399921.jpg
# 2022-01-04 02:15:19      14968 data_prep_workshop/pytorch/data/train/00/000000400299.jpg
# 2022-01-04 02:15:15      22295 data_prep_workshop/pytorch/data/train/00/000000401518.jpg
# 2021-12-28 07:37:33      18735 data_prep_workshop/pytorch/data/train/00/000000402206.jpg
# 2022-01-04 02:15:18      14319 data_prep_workshop/pytorch/data/train/00/000000407545.jpg
# 2022-01-04 02:15:17      17146 data_prep_workshop/pytorch/data/train/00/000000408660.jpg
# 2022-01-04 02:15:18      22442 data_prep_workshop/pytorch/data/train/00/000000411475.jpg
# 2022-01-04 02:15:24      10070 data_prep_workshop/pytorch/data/train/00/000000412842.jpg
# 2022-01-04 02:15:24      12027 data_prep_workshop/pytorch/data/train/00/000000414261.jpg
# 2022-01-04 02:15:15      19959 data_prep_workshop/pytorch/data/train/00/000000416476.jpg
# 2022-01-04 02:15:18      10978 data_prep_workshop/pytorch/data/train/00/000000419228.jpg
# 2022-01-04 02:15:21      18387 data_prep_workshop/pytorch/data/train/00/000000419604.jpg
# 2022-01-04 02:15:22       9746 data_prep_workshop/pytorch/data/train/00/000000421144.jpg
# 2021-12-28 07:37:33      19610 data_prep_workshop/pytorch/data/train/00/000000421986.jpg
# 2022-01-04 02:15:19      15795 data_prep_workshop/pytorch/data/train/00/000000423909.jpg
# 2021-12-28 07:37:33      15003 data_prep_workshop/pytorch/data/train/00/000000424431.jpg
# 2022-01-04 02:15:15      19896 data_prep_workshop/pytorch/data/train/00/000000429949.jpg
# 2022-01-04 02:15:21      20607 data_prep_workshop/pytorch/data/train/00/000000430681.jpg
# 2022-01-04 02:15:23      21030 data_prep_workshop/pytorch/data/train/00/000000430805.jpg
# 2022-01-04 02:15:22      14207 data_prep_workshop/pytorch/data/train/00/000000431304.jpg
# 2022-01-04 02:15:15      20496 data_prep_workshop/pytorch/data/train/00/000000431727.jpg
# 2021-12-28 07:37:33      14959 data_prep_workshop/pytorch/data/train/00/000000432414.jpg
# 2022-01-04 02:15:15      16736 data_prep_workshop/pytorch/data/train/00/000000432675.jpg
# 2022-01-04 02:15:18      13164 data_prep_workshop/pytorch/data/train/00/000000436793.jpg
# 2022-01-04 02:15:24      29661 data_prep_workshop/pytorch/data/train/00/000000436936.jpg
# 2022-01-04 02:15:23      14931 data_prep_workshop/pytorch/data/train/00/000000438427.jpg
# 2022-01-04 02:15:16      19986 data_prep_workshop/pytorch/data/train/00/000000441054.jpg
# 2022-01-04 02:15:21      15926 data_prep_workshop/pytorch/data/train/00/000000447932.jpg
# 2022-01-04 02:15:18      11164 data_prep_workshop/pytorch/data/train/00/000000448696.jpg
# 2022-01-04 02:15:17      19352 data_prep_workshop/pytorch/data/train/00/000000449195.jpg
# 2022-01-04 02:15:21      16679 data_prep_workshop/pytorch/data/train/00/000000454314.jpg
# 2022-01-04 02:15:20      15402 data_prep_workshop/pytorch/data/train/00/000000458177.jpg
# 2022-01-04 02:15:20      17328 data_prep_workshop/pytorch/data/train/00/000000461477.jpg
# 2022-01-04 02:15:24      14711 data_prep_workshop/pytorch/data/train/00/000000465697.jpg
# 2022-01-04 02:15:24       8423 data_prep_workshop/pytorch/data/train/00/000000469181.jpg
# 2022-01-04 02:15:21      24458 data_prep_workshop/pytorch/data/train/00/000000472823.jpg
# 2022-01-04 02:15:23      12259 data_prep_workshop/pytorch/data/train/00/000000474502.jpg
# 2022-01-04 02:15:14      11484 data_prep_workshop/pytorch/data/train/00/000000475465.jpg
# 2021-12-28 07:37:33      22336 data_prep_workshop/pytorch/data/train/00/000000478029.jpg
# 2022-01-04 02:15:23      19159 data_prep_workshop/pytorch/data/train/00/000000479331.jpg
# 2022-01-04 02:15:23      19979 data_prep_workshop/pytorch/data/train/00/000000487009.jpg
# 2022-01-04 02:15:15      11036 data_prep_workshop/pytorch/data/train/00/000000491505.jpg
# 2022-01-04 02:15:21      15897 data_prep_workshop/pytorch/data/train/00/000000492510.jpg
# 2022-01-04 02:15:20      14368 data_prep_workshop/pytorch/data/train/00/000000493067.jpg
# 2022-01-04 02:15:16      17477 data_prep_workshop/pytorch/data/train/00/000000494998.jpg
# 2022-01-04 02:15:22      17219 data_prep_workshop/pytorch/data/train/00/000000495199.jpg
# 2021-12-28 07:37:33       9406 data_prep_workshop/pytorch/data/train/00/000000498460.jpg
# 2022-01-04 02:15:23      16704 data_prep_workshop/pytorch/data/train/00/000000498493.jpg
# 2022-01-04 02:15:17      19998 data_prep_workshop/pytorch/data/train/00/000000502084.jpg
# 2022-01-04 02:15:21      15536 data_prep_workshop/pytorch/data/train/00/000000503170.jpg
# 2022-01-04 02:15:16      15264 data_prep_workshop/pytorch/data/train/00/000000518455.jpg
# 2022-01-04 02:15:19      16359 data_prep_workshop/pytorch/data/train/00/000000520980.jpg
# 2022-01-04 02:15:20      15140 data_prep_workshop/pytorch/data/train/00/000000521125.jpg
# 2022-01-04 02:15:24      15040 data_prep_workshop/pytorch/data/train/00/000000522285.jpg
# 2022-01-04 02:15:25      20405 data_prep_workshop/pytorch/data/train/00/000000524263.jpg
# 2022-01-04 02:15:17      19888 data_prep_workshop/pytorch/data/train/00/000000527625.jpg
# 2022-01-04 02:15:25      13200 data_prep_workshop/pytorch/data/train/00/000000533446.jpg
# 2022-01-04 02:15:19      19709 data_prep_workshop/pytorch/data/train/00/000000533715.jpg
# 2022-01-04 02:15:20      14214 data_prep_workshop/pytorch/data/train/00/000000536517.jpg
# 2022-01-04 02:15:21      15709 data_prep_workshop/pytorch/data/train/00/000000539067.jpg
# 2022-01-04 02:15:14      18977 data_prep_workshop/pytorch/data/train/00/000000541880.jpg
# 2022-01-04 02:15:18      22136 data_prep_workshop/pytorch/data/train/00/000000543239.jpg
# 2022-01-04 02:15:22      20956 data_prep_workshop/pytorch/data/train/00/000000551739.jpg
# 2022-01-04 02:15:19      16063 data_prep_workshop/pytorch/data/train/00/000000561436.jpg
# 2022-01-04 02:15:23      19034 data_prep_workshop/pytorch/data/train/00/000000561763.jpg
# 2022-01-04 02:15:23      21363 data_prep_workshop/pytorch/data/train/00/000000565077.jpg
# 2022-01-04 02:15:17      13952 data_prep_workshop/pytorch/data/train/00/000000567454.jpg
# 2022-01-04 02:15:19      16314 data_prep_workshop/pytorch/data/train/00/000000571553.jpg
# 2022-01-04 02:15:14      11126 data_prep_workshop/pytorch/data/train/00/000000573509.jpg
# 2022-01-04 02:15:22      14367 data_prep_workshop/pytorch/data/train/00/000000574874.jpg
# 2022-01-04 02:15:18      13344 data_prep_workshop/pytorch/data/train/00/000000575666.jpg
# 2021-12-28 07:37:33      16151 data_prep_workshop/pytorch/data/train/00/000000580296.jpg
# 2022-01-04 02:15:14      11688 data_prep_workshop/pytorch/data/train/00/000000580390.jpg
# 2022-01-04 02:14:29       9226 data_prep_workshop/pytorch/data/train/01/000000001103.jpg
# 2022-01-04 02:14:24      20032 data_prep_workshop/pytorch/data/train/01/000000005259.jpg
# 2022-01-04 02:14:26      10590 data_prep_workshop/pytorch/data/train/01/000000007267.jpg
# 2022-01-04 02:14:20       8886 data_prep_workshop/pytorch/data/train/01/000000009668.jpg
# 2022-01-04 02:14:20      17780 data_prep_workshop/pytorch/data/train/01/000000012115.jpg
# 2022-01-04 02:14:29      19459 data_prep_workshop/pytorch/data/train/01/000000012647.jpg
# 2022-01-04 02:14:24       8325 data_prep_workshop/pytorch/data/train/01/000000015329.jpg
# 2022-01-04 02:14:19      18681 data_prep_workshop/pytorch/data/train/01/000000017392.jpg
# 2022-01-04 02:14:18      13198 data_prep_workshop/pytorch/data/train/01/000000017778.jpg
# 2022-01-04 02:14:20      15986 data_prep_workshop/pytorch/data/train/01/000000023419.jpg
# 2021-12-28 07:37:39       9270 data_prep_workshop/pytorch/data/train/01/000000024699.jpg
# 2022-01-04 02:14:29      12836 data_prep_workshop/pytorch/data/train/01/000000025959.jpg
# 2022-01-04 02:14:28      13553 data_prep_workshop/pytorch/data/train/01/000000026713.jpg
# 2022-01-04 02:14:29       6464 data_prep_workshop/pytorch/data/train/01/000000029616.jpg
# 2022-01-04 02:14:25      14368 data_prep_workshop/pytorch/data/train/01/000000030353.jpg
# 2022-01-04 02:14:24      13406 data_prep_workshop/pytorch/data/train/01/000000036414.jpg
# 2022-01-04 02:14:21       6913 data_prep_workshop/pytorch/data/train/01/000000038965.jpg
# 2022-01-04 02:14:27      23795 data_prep_workshop/pytorch/data/train/01/000000042165.jpg
# 2022-01-04 02:14:18      21424 data_prep_workshop/pytorch/data/train/01/000000042279.jpg
# 2022-01-04 02:14:19       9669 data_prep_workshop/pytorch/data/train/01/000000042849.jpg
# 2022-01-04 02:14:20      16948 data_prep_workshop/pytorch/data/train/01/000000043530.jpg
# 2021-12-28 07:37:39       7194 data_prep_workshop/pytorch/data/train/01/000000044123.jpg
# 2022-01-04 02:14:26      14296 data_prep_workshop/pytorch/data/train/01/000000045564.jpg
# 2022-01-04 02:14:21      17646 data_prep_workshop/pytorch/data/train/01/000000049633.jpg
# 2021-12-28 07:37:38      12454 data_prep_workshop/pytorch/data/train/01/000000051783.jpg
# 2021-12-28 07:37:38      12031 data_prep_workshop/pytorch/data/train/01/000000055299.jpg
# 2022-01-04 02:14:19       4480 data_prep_workshop/pytorch/data/train/01/000000056983.jpg
# 2022-01-04 02:14:24      13902 data_prep_workshop/pytorch/data/train/01/000000059451.jpg
# 2022-01-04 02:14:29       8562 data_prep_workshop/pytorch/data/train/01/000000060639.jpg
# 2022-01-04 02:14:23      14492 data_prep_workshop/pytorch/data/train/01/000000064030.jpg
# 2022-01-04 02:14:19      16620 data_prep_workshop/pytorch/data/train/01/000000067082.jpg
# 2022-01-04 02:14:27      13049 data_prep_workshop/pytorch/data/train/01/000000070856.jpg
# 2022-01-04 02:14:26       8227 data_prep_workshop/pytorch/data/train/01/000000075496.jpg
# 2022-01-04 02:14:24       8545 data_prep_workshop/pytorch/data/train/01/000000082007.jpg
# 2022-01-04 02:14:22      14042 data_prep_workshop/pytorch/data/train/01/000000082696.jpg
# 2022-01-04 02:14:24      18928 data_prep_workshop/pytorch/data/train/01/000000091160.jpg
# 2022-01-04 02:14:22      22018 data_prep_workshop/pytorch/data/train/01/000000091610.jpg
# 2022-01-04 02:14:19      10045 data_prep_workshop/pytorch/data/train/01/000000094010.jpg
# 2022-01-04 02:14:27      22851 data_prep_workshop/pytorch/data/train/01/000000096257.jpg
# 2022-01-04 02:14:21      10400 data_prep_workshop/pytorch/data/train/01/000000096459.jpg
# 2022-01-04 02:14:29       6271 data_prep_workshop/pytorch/data/train/01/000000097201.jpg
# 2022-01-04 02:14:24      17401 data_prep_workshop/pytorch/data/train/01/000000097211.jpg
# 2022-01-04 02:14:28       6873 data_prep_workshop/pytorch/data/train/01/000000098048.jpg
# 2022-01-04 02:14:28      15627 data_prep_workshop/pytorch/data/train/01/000000104130.jpg
# 2022-01-04 02:14:23      10233 data_prep_workshop/pytorch/data/train/01/000000104493.jpg
# 2021-12-28 07:37:38      11417 data_prep_workshop/pytorch/data/train/01/000000105909.jpg
# 2022-01-04 02:14:21      20451 data_prep_workshop/pytorch/data/train/01/000000107885.jpg
# 2022-01-04 02:14:22      18083 data_prep_workshop/pytorch/data/train/01/000000109498.jpg
# 2022-01-04 02:14:28      12513 data_prep_workshop/pytorch/data/train/01/000000118994.jpg
# 2022-01-04 02:14:24      17544 data_prep_workshop/pytorch/data/train/01/000000120420.jpg
# 2022-01-04 02:14:29      12569 data_prep_workshop/pytorch/data/train/01/000000120977.jpg
# 2022-01-04 02:14:21       9620 data_prep_workshop/pytorch/data/train/01/000000121193.jpg
# 2022-01-04 02:14:25      10106 data_prep_workshop/pytorch/data/train/01/000000123664.jpg
# 2022-01-04 02:14:23      12875 data_prep_workshop/pytorch/data/train/01/000000125535.jpg
# 2022-01-04 02:14:19      10571 data_prep_workshop/pytorch/data/train/01/000000129159.jpg
# 2021-12-28 07:37:38      12990 data_prep_workshop/pytorch/data/train/01/000000130647.jpg
# 2022-01-04 02:14:25      17204 data_prep_workshop/pytorch/data/train/01/000000131460.jpg
# 2022-01-04 02:14:21      11225 data_prep_workshop/pytorch/data/train/01/000000137490.jpg
# 2022-01-04 02:14:20       9484 data_prep_workshop/pytorch/data/train/01/000000141003.jpg
# 2022-01-04 02:14:26       9901 data_prep_workshop/pytorch/data/train/01/000000141755.jpg
# 2022-01-04 02:14:28      10259 data_prep_workshop/pytorch/data/train/01/000000149738.jpg
# 2022-01-04 02:14:28      17324 data_prep_workshop/pytorch/data/train/01/000000153092.jpg
# 2022-01-04 02:14:21      21639 data_prep_workshop/pytorch/data/train/01/000000153604.jpg
# 2022-01-04 02:14:27      13035 data_prep_workshop/pytorch/data/train/01/000000159421.jpg
# 2022-01-04 02:14:23       7867 data_prep_workshop/pytorch/data/train/01/000000168574.jpg
# 2022-01-04 02:14:20       7985 data_prep_workshop/pytorch/data/train/01/000000168978.jpg
# 2022-01-04 02:14:28      14045 data_prep_workshop/pytorch/data/train/01/000000169035.jpg
# 2022-01-04 02:14:21      11184 data_prep_workshop/pytorch/data/train/01/000000172271.jpg
# 2022-01-04 02:14:19      22731 data_prep_workshop/pytorch/data/train/01/000000176847.jpg
# 2022-01-04 02:14:22       6980 data_prep_workshop/pytorch/data/train/01/000000178708.jpg
# 2022-01-04 02:14:23       9461 data_prep_workshop/pytorch/data/train/01/000000181488.jpg
# 2022-01-04 02:14:20      13416 data_prep_workshop/pytorch/data/train/01/000000181626.jpg
# 2022-01-04 02:14:26      15883 data_prep_workshop/pytorch/data/train/01/000000187462.jpg
# 2022-01-04 02:14:25       7232 data_prep_workshop/pytorch/data/train/01/000000188181.jpg
# 2022-01-04 02:14:22      13995 data_prep_workshop/pytorch/data/train/01/000000188660.jpg
# 2022-01-04 02:14:21      12134 data_prep_workshop/pytorch/data/train/01/000000192160.jpg
# 2022-01-04 02:14:28      22682 data_prep_workshop/pytorch/data/train/01/000000192394.jpg
# 2022-01-04 02:14:23      10809 data_prep_workshop/pytorch/data/train/01/000000195124.jpg
# 2022-01-04 02:14:24      19605 data_prep_workshop/pytorch/data/train/01/000000195401.jpg
# 2022-01-04 02:14:19      14286 data_prep_workshop/pytorch/data/train/01/000000202273.jpg
# 2022-01-04 02:14:20       9899 data_prep_workshop/pytorch/data/train/01/000000204015.jpg
# 2022-01-04 02:14:22      16275 data_prep_workshop/pytorch/data/train/01/000000205067.jpg
# 2022-01-04 02:14:24       9255 data_prep_workshop/pytorch/data/train/01/000000209062.jpg
# 2022-01-04 02:14:27      15023 data_prep_workshop/pytorch/data/train/01/000000209685.jpg
# 2021-12-28 07:37:39      19706 data_prep_workshop/pytorch/data/train/01/000000210208.jpg
# 2022-01-04 02:14:18      11176 data_prep_workshop/pytorch/data/train/01/000000210346.jpg
# 2022-01-04 02:14:19       7425 data_prep_workshop/pytorch/data/train/01/000000211063.jpg
# 2022-01-04 02:14:19      10324 data_prep_workshop/pytorch/data/train/01/000000213936.jpg
# 2022-01-04 02:14:19      14864 data_prep_workshop/pytorch/data/train/01/000000218603.jpg
# 2021-12-28 07:37:38      12586 data_prep_workshop/pytorch/data/train/01/000000220858.jpg
# 2022-01-04 02:14:21      16126 data_prep_workshop/pytorch/data/train/01/000000226162.jpg
# 2022-01-04 02:14:24      12124 data_prep_workshop/pytorch/data/train/01/000000230669.jpg
# 2022-01-04 02:14:25      11171 data_prep_workshop/pytorch/data/train/01/000000231362.jpg
# 2022-01-04 02:14:28      17583 data_prep_workshop/pytorch/data/train/01/000000233039.jpg
# 2022-01-04 02:14:20      12095 data_prep_workshop/pytorch/data/train/01/000000244231.jpg
# 2022-01-04 02:14:26      10181 data_prep_workshop/pytorch/data/train/01/000000247223.jpg
# 2022-01-04 02:14:24      23148 data_prep_workshop/pytorch/data/train/01/000000249306.jpg
# 2022-01-04 02:14:28      19185 data_prep_workshop/pytorch/data/train/01/000000254449.jpg
# 2022-01-04 02:14:26      22924 data_prep_workshop/pytorch/data/train/01/000000254645.jpg
# 2022-01-04 02:14:29      12359 data_prep_workshop/pytorch/data/train/01/000000256794.jpg
# 2022-01-04 02:14:27      10473 data_prep_workshop/pytorch/data/train/01/000000258285.jpg
# 2022-01-04 02:14:29      18457 data_prep_workshop/pytorch/data/train/01/000000258789.jpg
# 2022-01-04 02:14:22      10079 data_prep_workshop/pytorch/data/train/01/000000261761.jpg
# 2022-01-04 02:14:23      21217 data_prep_workshop/pytorch/data/train/01/000000261906.jpg
# 2022-01-04 02:14:19      12099 data_prep_workshop/pytorch/data/train/01/000000263231.jpg
# 2022-01-04 02:14:26      13145 data_prep_workshop/pytorch/data/train/01/000000264659.jpg
# 2022-01-04 02:14:23      10057 data_prep_workshop/pytorch/data/train/01/000000268927.jpg
# 2022-01-04 02:14:22       8142 data_prep_workshop/pytorch/data/train/01/000000270089.jpg
# 2021-12-28 07:37:38      18135 data_prep_workshop/pytorch/data/train/01/000000270478.jpg
# 2022-01-04 02:14:20      12362 data_prep_workshop/pytorch/data/train/01/000000273710.jpg
# 2022-01-04 02:14:24      19886 data_prep_workshop/pytorch/data/train/01/000000273904.jpg
# 2022-01-04 02:14:23       4576 data_prep_workshop/pytorch/data/train/01/000000275995.jpg
# 2022-01-04 02:14:25       9882 data_prep_workshop/pytorch/data/train/01/000000278306.jpg
# 2022-01-04 02:14:27       9979 data_prep_workshop/pytorch/data/train/01/000000281581.jpg
# 2022-01-04 02:14:26      22116 data_prep_workshop/pytorch/data/train/01/000000285037.jpg
# 2022-01-04 02:14:29      10286 data_prep_workshop/pytorch/data/train/01/000000289855.jpg
# 2022-01-04 02:14:26      18605 data_prep_workshop/pytorch/data/train/01/000000297017.jpg
# 2022-01-04 02:14:21      18839 data_prep_workshop/pytorch/data/train/01/000000297419.jpg
# 2022-01-04 02:14:18      17146 data_prep_workshop/pytorch/data/train/01/000000298788.jpg
# 2022-01-04 02:14:25      25953 data_prep_workshop/pytorch/data/train/01/000000299568.jpg
# 2022-01-04 02:14:21      12641 data_prep_workshop/pytorch/data/train/01/000000303318.jpg
# 2022-01-04 02:14:29      11870 data_prep_workshop/pytorch/data/train/01/000000303330.jpg
# 2021-12-28 07:37:39      14736 data_prep_workshop/pytorch/data/train/01/000000303439.jpg
# 2022-01-04 02:14:26      17872 data_prep_workshop/pytorch/data/train/01/000000304580.jpg
# 2022-01-04 02:14:26      17535 data_prep_workshop/pytorch/data/train/01/000000307790.jpg
# 2022-01-04 02:14:27      20231 data_prep_workshop/pytorch/data/train/01/000000309264.jpg
# 2022-01-04 02:14:28      16615 data_prep_workshop/pytorch/data/train/01/000000309869.jpg
# 2022-01-04 02:14:19      11374 data_prep_workshop/pytorch/data/train/01/000000310879.jpg
# 2022-01-04 02:14:28      11529 data_prep_workshop/pytorch/data/train/01/000000311062.jpg
# 2022-01-04 02:14:29      20968 data_prep_workshop/pytorch/data/train/01/000000316658.jpg
# 2022-01-04 02:14:23      18935 data_prep_workshop/pytorch/data/train/01/000000322091.jpg
# 2022-01-04 02:14:29      13174 data_prep_workshop/pytorch/data/train/01/000000326357.jpg
# 2022-01-04 02:14:19      12348 data_prep_workshop/pytorch/data/train/01/000000327176.jpg
# 2021-12-28 07:37:38      12201 data_prep_workshop/pytorch/data/train/01/000000329553.jpg
# 2022-01-04 02:14:20       6743 data_prep_workshop/pytorch/data/train/01/000000334585.jpg
# 2022-01-04 02:14:28      13455 data_prep_workshop/pytorch/data/train/01/000000337425.jpg
# 2022-01-04 02:14:21      18713 data_prep_workshop/pytorch/data/train/01/000000337987.jpg
# 2022-01-04 02:14:29       6309 data_prep_workshop/pytorch/data/train/01/000000338468.jpg
# 2022-01-04 02:14:25       6365 data_prep_workshop/pytorch/data/train/01/000000338597.jpg
# 2021-12-28 07:37:39      17446 data_prep_workshop/pytorch/data/train/01/000000340174.jpg
# 2022-01-04 02:14:27      17884 data_prep_workshop/pytorch/data/train/01/000000344214.jpg
# 2022-01-04 02:14:22       9165 data_prep_workshop/pytorch/data/train/01/000000353138.jpg
# 2021-12-28 07:37:39      10891 data_prep_workshop/pytorch/data/train/01/000000357871.jpg
# 2022-01-04 02:14:25      22267 data_prep_workshop/pytorch/data/train/01/000000360317.jpg
# 2022-01-04 02:14:21      16053 data_prep_workshop/pytorch/data/train/01/000000366150.jpg
# 2022-01-04 02:14:19      11328 data_prep_workshop/pytorch/data/train/01/000000371939.jpg
# 2021-12-28 07:37:38      10320 data_prep_workshop/pytorch/data/train/01/000000373197.jpg
# 2022-01-04 02:14:23      11392 data_prep_workshop/pytorch/data/train/01/000000373591.jpg
# 2022-01-04 02:14:21       9003 data_prep_workshop/pytorch/data/train/01/000000375405.jpg
# 2022-01-04 02:14:19      14856 data_prep_workshop/pytorch/data/train/01/000000376090.jpg
# 2021-12-28 07:37:38       8690 data_prep_workshop/pytorch/data/train/01/000000379558.jpg
# 2022-01-04 02:14:29      11985 data_prep_workshop/pytorch/data/train/01/000000386919.jpg
# 2022-01-04 02:14:20      25839 data_prep_workshop/pytorch/data/train/01/000000387597.jpg
# 2022-01-04 02:14:23      11300 data_prep_workshop/pytorch/data/train/01/000000391857.jpg
# 2022-01-04 02:14:20      15325 data_prep_workshop/pytorch/data/train/01/000000392381.jpg
# 2022-01-04 02:14:18      11698 data_prep_workshop/pytorch/data/train/01/000000392666.jpg
# 2022-01-04 02:14:19      15630 data_prep_workshop/pytorch/data/train/01/000000401392.jpg
# 2022-01-04 02:14:22      17947 data_prep_workshop/pytorch/data/train/01/000000407387.jpg
# 2022-01-04 02:14:25       8366 data_prep_workshop/pytorch/data/train/01/000000407825.jpg
# 2022-01-04 02:14:20      10169 data_prep_workshop/pytorch/data/train/01/000000411215.jpg
# 2022-01-04 02:14:28      21269 data_prep_workshop/pytorch/data/train/01/000000413959.jpg
# 2022-01-04 02:14:26      13015 data_prep_workshop/pytorch/data/train/01/000000415663.jpg
# 2022-01-04 02:14:22      16392 data_prep_workshop/pytorch/data/train/01/000000420864.jpg
# 2022-01-04 02:14:29      15993 data_prep_workshop/pytorch/data/train/01/000000423620.jpg
# 2022-01-04 02:14:24      11071 data_prep_workshop/pytorch/data/train/01/000000427491.jpg
# 2022-01-04 02:14:18      12361 data_prep_workshop/pytorch/data/train/01/000000429361.jpg
# 2022-01-04 02:14:24       9786 data_prep_workshop/pytorch/data/train/01/000000430537.jpg
# 2022-01-04 02:14:26      14354 data_prep_workshop/pytorch/data/train/01/000000431598.jpg
# 2022-01-04 02:14:23      22912 data_prep_workshop/pytorch/data/train/01/000000431931.jpg
# 2022-01-04 02:14:20      10105 data_prep_workshop/pytorch/data/train/01/000000435010.jpg
# 2021-12-28 07:37:38      12539 data_prep_workshop/pytorch/data/train/01/000000435139.jpg
# 2022-01-04 02:14:24      13724 data_prep_workshop/pytorch/data/train/01/000000436303.jpg
# 2022-01-04 02:14:20      12191 data_prep_workshop/pytorch/data/train/01/000000436843.jpg
# 2021-12-28 07:37:38      12949 data_prep_workshop/pytorch/data/train/01/000000439089.jpg
# 2022-01-04 02:14:20      11838 data_prep_workshop/pytorch/data/train/01/000000439274.jpg
# 2021-12-28 07:37:39      16884 data_prep_workshop/pytorch/data/train/01/000000440706.jpg
# 2022-01-04 02:14:23       7310 data_prep_workshop/pytorch/data/train/01/000000442732.jpg
# 2021-12-28 07:37:39      17131 data_prep_workshop/pytorch/data/train/01/000000443749.jpg
# 2022-01-04 02:14:23      10051 data_prep_workshop/pytorch/data/train/01/000000444272.jpg
# 2022-01-04 02:14:27       9602 data_prep_workshop/pytorch/data/train/01/000000449727.jpg
# 2022-01-04 02:14:28      13239 data_prep_workshop/pytorch/data/train/01/000000451976.jpg
# 2022-01-04 02:14:24      23479 data_prep_workshop/pytorch/data/train/01/000000455601.jpg
# 2021-12-28 07:37:38      12194 data_prep_workshop/pytorch/data/train/01/000000456065.jpg
# 2022-01-04 02:14:29      17137 data_prep_workshop/pytorch/data/train/01/000000457383.jpg
# 2022-01-04 02:14:25      27566 data_prep_workshop/pytorch/data/train/01/000000458413.jpg
# 2022-01-04 02:14:20      13748 data_prep_workshop/pytorch/data/train/01/000000461336.jpg
# 2022-01-04 02:14:27       9034 data_prep_workshop/pytorch/data/train/01/000000462341.jpg
# 2022-01-04 02:14:24      10574 data_prep_workshop/pytorch/data/train/01/000000462978.jpg
# 2022-01-04 02:14:19      14004 data_prep_workshop/pytorch/data/train/01/000000464251.jpg
# 2022-01-04 02:14:23      14331 data_prep_workshop/pytorch/data/train/01/000000474780.jpg
# 2021-12-28 07:37:38      22233 data_prep_workshop/pytorch/data/train/01/000000475169.jpg
# 2022-01-04 02:14:27       5948 data_prep_workshop/pytorch/data/train/01/000000481558.jpg
# 2022-01-04 02:14:22       3682 data_prep_workshop/pytorch/data/train/01/000000483199.jpg
# 2021-12-28 07:37:38      21772 data_prep_workshop/pytorch/data/train/01/000000488316.jpg
# 2022-01-04 02:14:27       8414 data_prep_workshop/pytorch/data/train/01/000000492214.jpg
# 2022-01-04 02:14:22      16426 data_prep_workshop/pytorch/data/train/01/000000495048.jpg
# 2022-01-04 02:14:26      10612 data_prep_workshop/pytorch/data/train/01/000000500092.jpg
# 2022-01-04 02:14:25      23177 data_prep_workshop/pytorch/data/train/01/000000509691.jpg
# 2022-01-04 02:14:24      10937 data_prep_workshop/pytorch/data/train/01/000000512411.jpg
# 2021-12-28 07:37:38      11494 data_prep_workshop/pytorch/data/train/01/000000518667.jpg
# 2021-12-28 07:37:38      19633 data_prep_workshop/pytorch/data/train/01/000000520482.jpg
# 2022-01-04 02:14:26      19461 data_prep_workshop/pytorch/data/train/01/000000520879.jpg
# 2022-01-04 02:14:19      16114 data_prep_workshop/pytorch/data/train/01/000000521631.jpg
# 2022-01-04 02:14:22      12799 data_prep_workshop/pytorch/data/train/01/000000521881.jpg
# 2022-01-04 02:14:26       6782 data_prep_workshop/pytorch/data/train/01/000000523250.jpg
# 2022-01-04 02:14:18      16352 data_prep_workshop/pytorch/data/train/01/000000525999.jpg
# 2022-01-04 02:14:22      14508 data_prep_workshop/pytorch/data/train/01/000000533807.jpg
# 2022-01-04 02:14:23      13495 data_prep_workshop/pytorch/data/train/01/000000534312.jpg
# 2022-01-04 02:14:21      11550 data_prep_workshop/pytorch/data/train/01/000000535563.jpg
# 2022-01-04 02:14:28       4498 data_prep_workshop/pytorch/data/train/01/000000536110.jpg
# 2022-01-04 02:14:25      10582 data_prep_workshop/pytorch/data/train/01/000000538423.jpg
# 2022-01-04 02:14:29      19229 data_prep_workshop/pytorch/data/train/01/000000541571.jpg
# 2022-01-04 02:14:29      12392 data_prep_workshop/pytorch/data/train/01/000000546454.jpg
# 2022-01-04 02:14:21       8318 data_prep_workshop/pytorch/data/train/01/000000550341.jpg
# 2022-01-04 02:14:18      10525 data_prep_workshop/pytorch/data/train/01/000000552112.jpg
# 2022-01-04 02:14:26       8953 data_prep_workshop/pytorch/data/train/01/000000552420.jpg
# 2022-01-04 02:14:23      18682 data_prep_workshop/pytorch/data/train/01/000000556207.jpg
# 2022-01-04 02:14:25      13486 data_prep_workshop/pytorch/data/train/01/000000556683.jpg
# 2022-01-04 02:14:28      18271 data_prep_workshop/pytorch/data/train/01/000000559127.jpg
# 2022-01-04 02:14:25       6985 data_prep_workshop/pytorch/data/train/01/000000560242.jpg
# 2022-01-04 02:14:19      15240 data_prep_workshop/pytorch/data/train/01/000000560640.jpg
# 2022-01-04 02:14:18       9760 data_prep_workshop/pytorch/data/train/01/000000563762.jpg
# 2022-01-04 02:14:28      16913 data_prep_workshop/pytorch/data/train/01/000000566128.jpg
# 2022-01-04 02:14:23      15587 data_prep_workshop/pytorch/data/train/01/000000571646.jpg
# 2022-01-04 02:14:26      19705 data_prep_workshop/pytorch/data/train/01/000000571948.jpg
# 2022-01-04 02:14:21       5679 data_prep_workshop/pytorch/data/train/01/000000572830.jpg
# 2022-01-04 02:14:27       8430 data_prep_workshop/pytorch/data/train/01/000000573479.jpg
# 2022-01-04 02:14:19      11536 data_prep_workshop/pytorch/data/train/01/000000573762.jpg
# 2022-01-04 02:14:28       9123 data_prep_workshop/pytorch/data/train/01/000000576749.jpg
# 2022-01-04 02:14:25      10408 data_prep_workshop/pytorch/data/train/01/000000578236.jpg
# 2022-01-04 02:14:26       4729 data_prep_workshop/pytorch/data/train/01/000000580931.jpg
# 2022-01-04 02:14:25      12759 data_prep_workshop/pytorch/data/train/01/000000581702.jpg
# 2022-01-04 02:15:02      10512 data_prep_workshop/pytorch/data/train/02/000000001942.jpg
# 2022-01-04 02:14:53      11268 data_prep_workshop/pytorch/data/train/02/000000008786.jpg
# 2022-01-04 02:14:55       7665 data_prep_workshop/pytorch/data/train/02/000000009170.jpg
# 2022-01-04 02:14:54      12944 data_prep_workshop/pytorch/data/train/02/000000012070.jpg
# 2022-01-04 02:14:52      15135 data_prep_workshop/pytorch/data/train/02/000000014940.jpg
# 2022-01-04 02:14:53      17706 data_prep_workshop/pytorch/data/train/02/000000015297.jpg
# 2021-12-28 07:37:33      14301 data_prep_workshop/pytorch/data/train/02/000000017065.jpg
# 2022-01-04 02:14:53      11774 data_prep_workshop/pytorch/data/train/02/000000022759.jpg
# 2022-01-04 02:14:55      14420 data_prep_workshop/pytorch/data/train/02/000000025551.jpg
# 2022-01-04 02:14:56       8140 data_prep_workshop/pytorch/data/train/02/000000028903.jpg
# 2022-01-04 02:15:00       8890 data_prep_workshop/pytorch/data/train/02/000000029145.jpg
# 2022-01-04 02:14:55       7620 data_prep_workshop/pytorch/data/train/02/000000030997.jpg
# 2022-01-04 02:15:02      13778 data_prep_workshop/pytorch/data/train/02/000000035774.jpg
# 2022-01-04 02:14:59      13844 data_prep_workshop/pytorch/data/train/02/000000036942.jpg
# 2022-01-04 02:15:02      11801 data_prep_workshop/pytorch/data/train/02/000000041392.jpg
# 2022-01-04 02:15:01      16222 data_prep_workshop/pytorch/data/train/02/000000048530.jpg
# 2022-01-04 02:14:59      12598 data_prep_workshop/pytorch/data/train/02/000000049810.jpg
# 2022-01-04 02:14:58      10056 data_prep_workshop/pytorch/data/train/02/000000050790.jpg
# 2022-01-04 02:15:02      10657 data_prep_workshop/pytorch/data/train/02/000000052290.jpg
# 2021-12-28 07:37:32       9709 data_prep_workshop/pytorch/data/train/02/000000053479.jpg
# 2022-01-04 02:14:58      13271 data_prep_workshop/pytorch/data/train/02/000000055363.jpg
# 2022-01-04 02:14:54      12637 data_prep_workshop/pytorch/data/train/02/000000061389.jpg
# 2022-01-04 02:14:56       8549 data_prep_workshop/pytorch/data/train/02/000000062237.jpg
# 2022-01-04 02:15:00      11267 data_prep_workshop/pytorch/data/train/02/000000063970.jpg
# 2022-01-04 02:14:56      16024 data_prep_workshop/pytorch/data/train/02/000000065166.jpg
# 2022-01-04 02:15:00      10051 data_prep_workshop/pytorch/data/train/02/000000074825.jpg
# 2022-01-04 02:15:01      21717 data_prep_workshop/pytorch/data/train/02/000000075586.jpg
# 2022-01-04 02:15:01       9185 data_prep_workshop/pytorch/data/train/02/000000076522.jpg
# 2022-01-04 02:14:56      13901 data_prep_workshop/pytorch/data/train/02/000000077417.jpg
# 2022-01-04 02:15:00      13547 data_prep_workshop/pytorch/data/train/02/000000078420.jpg
# 2021-12-28 07:37:32      10255 data_prep_workshop/pytorch/data/train/02/000000084362.jpg
# 2022-01-04 02:15:00      12199 data_prep_workshop/pytorch/data/train/02/000000085728.jpg
# 2022-01-04 02:15:02      13248 data_prep_workshop/pytorch/data/train/02/000000086137.jpg
# 2022-01-04 02:14:55      11285 data_prep_workshop/pytorch/data/train/02/000000086205.jpg
# 2022-01-04 02:14:55      13131 data_prep_workshop/pytorch/data/train/02/000000087871.jpg
# 2022-01-04 02:15:01      11778 data_prep_workshop/pytorch/data/train/02/000000092480.jpg
# 2022-01-04 02:14:54      11460 data_prep_workshop/pytorch/data/train/02/000000094340.jpg
# 2021-12-28 07:37:32      12665 data_prep_workshop/pytorch/data/train/02/000000094536.jpg
# 2022-01-04 02:14:56      10074 data_prep_workshop/pytorch/data/train/02/000000094566.jpg
# 2022-01-04 02:14:55      15481 data_prep_workshop/pytorch/data/train/02/000000102319.jpg
# 2022-01-04 02:15:01       8728 data_prep_workshop/pytorch/data/train/02/000000103940.jpg
# 2022-01-04 02:14:54      11205 data_prep_workshop/pytorch/data/train/02/000000105658.jpg
# 2022-01-04 02:14:55      18273 data_prep_workshop/pytorch/data/train/02/000000106296.jpg
# 2021-12-28 07:37:32      11009 data_prep_workshop/pytorch/data/train/02/000000107087.jpg
# 2022-01-04 02:14:54      10639 data_prep_workshop/pytorch/data/train/02/000000108244.jpg
# 2022-01-04 02:14:54      16696 data_prep_workshop/pytorch/data/train/02/000000108556.jpg
# 2022-01-04 02:14:53      11993 data_prep_workshop/pytorch/data/train/02/000000109836.jpg
# 2022-01-04 02:14:51      10297 data_prep_workshop/pytorch/data/train/02/000000116503.jpg
# 2022-01-04 02:15:01      10650 data_prep_workshop/pytorch/data/train/02/000000118889.jpg
# 2022-01-04 02:14:59      11574 data_prep_workshop/pytorch/data/train/02/000000119360.jpg
# 2022-01-04 02:14:57      15113 data_prep_workshop/pytorch/data/train/02/000000119938.jpg
# 2022-01-04 02:14:55      12030 data_prep_workshop/pytorch/data/train/02/000000120099.jpg
# 2022-01-04 02:14:58       9815 data_prep_workshop/pytorch/data/train/02/000000121783.jpg
# 2022-01-04 02:14:52      12400 data_prep_workshop/pytorch/data/train/02/000000123916.jpg
# 2022-01-04 02:15:01      11079 data_prep_workshop/pytorch/data/train/02/000000130183.jpg
# 2022-01-04 02:14:59      11212 data_prep_workshop/pytorch/data/train/02/000000131131.jpg
# 2022-01-04 02:14:53       9930 data_prep_workshop/pytorch/data/train/02/000000137514.jpg
# 2021-12-28 07:37:33      12924 data_prep_workshop/pytorch/data/train/02/000000137970.jpg
# 2022-01-04 02:14:59      11897 data_prep_workshop/pytorch/data/train/02/000000139721.jpg
# 2022-01-04 02:14:59      10324 data_prep_workshop/pytorch/data/train/02/000000148525.jpg
# 2022-01-04 02:14:54      14325 data_prep_workshop/pytorch/data/train/02/000000149222.jpg
# 2022-01-04 02:14:55      14389 data_prep_workshop/pytorch/data/train/02/000000159170.jpg
# 2022-01-04 02:14:52      14271 data_prep_workshop/pytorch/data/train/02/000000160201.jpg
# 2022-01-04 02:15:00      19547 data_prep_workshop/pytorch/data/train/02/000000168356.jpg
# 2022-01-04 02:14:56       8944 data_prep_workshop/pytorch/data/train/02/000000168543.jpg
# 2022-01-04 02:14:58       9199 data_prep_workshop/pytorch/data/train/02/000000168847.jpg
# 2022-01-04 02:14:55       7908 data_prep_workshop/pytorch/data/train/02/000000168948.jpg
# 2022-01-04 02:15:00      13723 data_prep_workshop/pytorch/data/train/02/000000174527.jpg
# 2022-01-04 02:15:00      11579 data_prep_workshop/pytorch/data/train/02/000000174573.jpg
# 2022-01-04 02:15:02       7318 data_prep_workshop/pytorch/data/train/02/000000180129.jpg
# 2022-01-04 02:15:02      12423 data_prep_workshop/pytorch/data/train/02/000000180960.jpg
# 2022-01-04 02:14:52      10755 data_prep_workshop/pytorch/data/train/02/000000182867.jpg
# 2022-01-04 02:15:00      16004 data_prep_workshop/pytorch/data/train/02/000000183626.jpg
# 2022-01-04 02:14:55       6516 data_prep_workshop/pytorch/data/train/02/000000185773.jpg
# 2022-01-04 02:14:53       9622 data_prep_workshop/pytorch/data/train/02/000000186635.jpg
# 2022-01-04 02:14:58      12662 data_prep_workshop/pytorch/data/train/02/000000188459.jpg
# 2022-01-04 02:14:53       9609 data_prep_workshop/pytorch/data/train/02/000000188639.jpg
# 2022-01-04 02:14:54      12607 data_prep_workshop/pytorch/data/train/02/000000188648.jpg
# 2022-01-04 02:14:51      14544 data_prep_workshop/pytorch/data/train/02/000000193680.jpg
# 2022-01-04 02:14:59      11268 data_prep_workshop/pytorch/data/train/02/000000195353.jpg
# 2022-01-04 02:14:58       9859 data_prep_workshop/pytorch/data/train/02/000000199141.jpg
# 2021-12-28 07:37:32      11950 data_prep_workshop/pytorch/data/train/02/000000204690.jpg
# 2022-01-04 02:15:01      14302 data_prep_workshop/pytorch/data/train/02/000000207077.jpg
# 2022-01-04 02:14:55      16715 data_prep_workshop/pytorch/data/train/02/000000212229.jpg
# 2022-01-04 02:14:52       8280 data_prep_workshop/pytorch/data/train/02/000000212868.jpg
# 2022-01-04 02:14:59       8472 data_prep_workshop/pytorch/data/train/02/000000217521.jpg
# 2021-12-28 07:37:32      13728 data_prep_workshop/pytorch/data/train/02/000000224974.jpg
# 2022-01-04 02:15:01      12223 data_prep_workshop/pytorch/data/train/02/000000226597.jpg
# 2022-01-04 02:14:53      12956 data_prep_workshop/pytorch/data/train/02/000000229494.jpg
# 2022-01-04 02:14:59      14773 data_prep_workshop/pytorch/data/train/02/000000230227.jpg
# ...
# 2022-01-04 02:15:59      21276 data_prep_workshop/pytorch/data/val/03/000000432172.jpg
# 2022-01-04 02:15:59      11475 data_prep_workshop/pytorch/data/val/03/000000460389.jpg
# 2022-01-04 02:15:59      16556 data_prep_workshop/pytorch/data/val/03/000000570452.jpg
# 2022-01-04 02:15:59      17273 data_prep_workshop/pytorch/data/val/03/000000573761.jpg
# 2022-01-04 02:15:57      14910 data_prep_workshop/pytorch/data/val/04/000000024159.jpg
# 2022-01-04 02:15:57      10444 data_prep_workshop/pytorch/data/val/04/000000041311.jpg
# 2022-01-04 02:15:57      15848 data_prep_workshop/pytorch/data/val/04/000000071313.jpg
# 2022-01-04 02:15:56      10775 data_prep_workshop/pytorch/data/val/04/000000075963.jpg
# 2022-01-04 02:15:57      19368 data_prep_workshop/pytorch/data/val/04/000000085114.jpg
# 2022-01-04 02:15:57      10371 data_prep_workshop/pytorch/data/val/04/000000086139.jpg
# 2022-01-04 02:15:57      11577 data_prep_workshop/pytorch/data/val/04/000000101461.jpg
# 2022-01-04 02:15:57       9141 data_prep_workshop/pytorch/data/val/04/000000108668.jpg
# 2022-01-04 02:15:57      13485 data_prep_workshop/pytorch/data/val/04/000000115721.jpg
# 2022-01-04 02:15:56      13603 data_prep_workshop/pytorch/data/val/04/000000115859.jpg
# 2022-01-04 02:15:56       9690 data_prep_workshop/pytorch/data/val/04/000000136720.jpg
# 2022-01-04 02:15:56      13678 data_prep_workshop/pytorch/data/val/04/000000147259.jpg
# 2022-01-04 02:15:57       7609 data_prep_workshop/pytorch/data/val/04/000000163496.jpg
# 2022-01-04 02:15:57       8572 data_prep_workshop/pytorch/data/val/04/000000172017.jpg
# 2022-01-04 02:15:56      15800 data_prep_workshop/pytorch/data/val/04/000000260699.jpg
# 2022-01-04 02:15:57      16192 data_prep_workshop/pytorch/data/val/04/000000263896.jpg
# 2022-01-04 02:15:57       9490 data_prep_workshop/pytorch/data/val/04/000000287427.jpg
# 2022-01-04 02:15:57      12327 data_prep_workshop/pytorch/data/val/04/000000304455.jpg
# 2022-01-04 02:15:56      11064 data_prep_workshop/pytorch/data/val/04/000000353858.jpg
# 2022-01-04 02:15:57      10259 data_prep_workshop/pytorch/data/val/04/000000361055.jpg
# 2022-01-04 02:15:57       7485 data_prep_workshop/pytorch/data/val/04/000000386637.jpg
# 2022-01-04 02:15:57       9712 data_prep_workshop/pytorch/data/val/04/000000455750.jpg
# 2022-01-04 02:15:56      12799 data_prep_workshop/pytorch/data/val/04/000000456825.jpg
# 2022-01-04 02:15:57      13120 data_prep_workshop/pytorch/data/val/04/000000499966.jpg
# 2022-01-04 02:15:56      13511 data_prep_workshop/pytorch/data/val/04/000000511307.jpg
# 2022-01-04 02:15:57      18534 data_prep_workshop/pytorch/data/val/04/000000557721.jpg
# 2022-01-04 02:15:56      19080 data_prep_workshop/pytorch/data/val/04/000000568238.jpg
# 2022-01-04 02:16:02      14303 data_prep_workshop/pytorch/data/val/05/000000102460.jpg
# 2022-01-04 02:16:03      10548 data_prep_workshop/pytorch/data/val/05/000000103723.jpg
# 2022-01-04 02:16:03      16990 data_prep_workshop/pytorch/data/val/05/000000199017.jpg
# 2022-01-04 02:16:03      18009 data_prep_workshop/pytorch/data/val/05/000000224874.jpg
# 2022-01-04 02:16:02      12672 data_prep_workshop/pytorch/data/val/05/000000268988.jpg
# 2022-01-04 02:16:03      12222 data_prep_workshop/pytorch/data/val/05/000000273118.jpg
# 2022-01-04 02:16:03      14019 data_prep_workshop/pytorch/data/val/05/000000286594.jpg
# 2022-01-04 02:16:03      16615 data_prep_workshop/pytorch/data/val/05/000000299438.jpg
# 2022-01-04 02:16:02      20936 data_prep_workshop/pytorch/data/val/05/000000301362.jpg
# 2022-01-04 02:16:03      13143 data_prep_workshop/pytorch/data/val/05/000000333705.jpg
# 2022-01-04 02:16:03      20188 data_prep_workshop/pytorch/data/val/05/000000341161.jpg
# 2022-01-04 02:16:03      18387 data_prep_workshop/pytorch/data/val/05/000000369512.jpg
# 2022-01-04 02:16:03      15734 data_prep_workshop/pytorch/data/val/05/000000398712.jpg
# 2022-01-04 02:16:03      18799 data_prep_workshop/pytorch/data/val/05/000000404795.jpg
# 2022-01-04 02:16:03      11568 data_prep_workshop/pytorch/data/val/05/000000488368.jpg
# 2022-01-04 02:16:02      13534 data_prep_workshop/pytorch/data/val/05/000000526565.jpg
# 2022-01-04 02:16:03      14287 data_prep_workshop/pytorch/data/val/05/000000535262.jpg
# 2022-01-04 02:16:02      11662 data_prep_workshop/pytorch/data/val/05/000000553366.jpg
# 2022-01-04 02:16:06       4698 data_prep_workshop/pytorch/data/val/06/alytes_obstetricans_s_000119.jpg
# 2022-01-04 02:16:06       4199 data_prep_workshop/pytorch/data/val/06/barking_frog_s_000598.jpg
# 2022-01-04 02:16:07       4261 data_prep_workshop/pytorch/data/val/06/bufo_speciosus_s_000071.jpg
# 2022-01-04 02:16:07       3274 data_prep_workshop/pytorch/data/val/06/bullfrog_s_002060.jpg
# 2022-01-04 02:16:07       3693 data_prep_workshop/pytorch/data/val/06/crapaud_s_000599.jpg
# 2022-01-04 02:16:07       5052 data_prep_workshop/pytorch/data/val/06/grass_frog_s_000596.jpg
# 2022-01-04 02:16:06       5039 data_prep_workshop/pytorch/data/val/06/green_frog_s_000609.jpg
# 2022-01-04 02:16:06       3449 data_prep_workshop/pytorch/data/val/06/green_frog_s_001058.jpg
# 2022-01-04 02:16:07       5205 data_prep_workshop/pytorch/data/val/06/leopard_frog_s_000557.jpg
# 2022-01-04 02:16:06       4147 data_prep_workshop/pytorch/data/val/06/leopard_frog_s_000737.jpg
# 2022-01-04 02:16:07       4642 data_prep_workshop/pytorch/data/val/06/leptodactylid_s_000021.jpg
# 2022-01-04 02:16:07       4124 data_prep_workshop/pytorch/data/val/06/pickerel_frog_s_001260.jpg
# 2022-01-04 02:16:07       5082 data_prep_workshop/pytorch/data/val/06/rana_catesbeiana_s_000265.jpg
# 2022-01-04 02:16:07       4246 data_prep_workshop/pytorch/data/val/06/spadefoot_s_000247.jpg
# 2022-01-04 02:16:07       4468 data_prep_workshop/pytorch/data/val/06/spring_frog_s_000833.jpg
# 2022-01-04 02:16:07       3458 data_prep_workshop/pytorch/data/val/06/toad_frog_s_001071.jpg
# 2022-01-04 02:16:07       4493 data_prep_workshop/pytorch/data/val/06/toad_s_000022.jpg
# 2022-01-04 02:16:06       3469 data_prep_workshop/pytorch/data/val/06/toad_s_000054.jpg
# 2022-01-04 02:16:06       4754 data_prep_workshop/pytorch/data/val/06/toad_s_001147.jpg
# 2022-01-04 02:16:07       4423 data_prep_workshop/pytorch/data/val/06/true_toad_s_000237.jpg
# 2022-01-04 02:16:06      21831 data_prep_workshop/pytorch/data/val/07/000000000025.jpg
# 2022-01-04 02:16:05      15130 data_prep_workshop/pytorch/data/val/07/000000038310.jpg
# 2022-01-04 02:16:06      15595 data_prep_workshop/pytorch/data/val/07/000000040621.jpg
# 2022-01-04 02:16:05      15600 data_prep_workshop/pytorch/data/val/07/000000060547.jpg
# 2022-01-04 02:16:06      19036 data_prep_workshop/pytorch/data/val/07/000000105469.jpg
# 2022-01-04 02:16:05       9920 data_prep_workshop/pytorch/data/val/07/000000231828.jpg
# 2022-01-04 02:16:06      17492 data_prep_workshop/pytorch/data/val/07/000000244222.jpg
# 2022-01-04 02:16:05      16607 data_prep_workshop/pytorch/data/val/07/000000254291.jpg
# 2022-01-04 02:16:06      15901 data_prep_workshop/pytorch/data/val/07/000000280409.jpg
# 2022-01-04 02:16:05      10229 data_prep_workshop/pytorch/data/val/07/000000299573.jpg
# 2022-01-04 02:16:05      11055 data_prep_workshop/pytorch/data/val/07/000000315018.jpg
# 2022-01-04 02:16:05      17826 data_prep_workshop/pytorch/data/val/07/000000366591.jpg
# 2022-01-04 02:16:06      19320 data_prep_workshop/pytorch/data/val/07/000000383282.jpg
# 2022-01-04 02:16:06      24798 data_prep_workshop/pytorch/data/val/07/000000444464.jpg
# 2022-01-04 02:16:06      24747 data_prep_workshop/pytorch/data/val/07/000000464178.jpg
# 2022-01-04 02:16:05      17123 data_prep_workshop/pytorch/data/val/07/000000500422.jpg
# 2022-01-04 02:16:05      23018 data_prep_workshop/pytorch/data/val/07/000000501022.jpg
# 2022-01-04 02:16:06      12378 data_prep_workshop/pytorch/data/val/07/000000511138.jpg
# 2022-01-04 02:16:06      12391 data_prep_workshop/pytorch/data/val/07/000000513099.jpg
# 2022-01-04 02:16:06      16568 data_prep_workshop/pytorch/data/val/07/000000566699.jpg
# 2022-01-04 02:16:06      16151 data_prep_workshop/pytorch/data/val/07/000000567375.jpg
# 2022-01-04 02:16:06      15742 data_prep_workshop/pytorch/data/val/07/000000574947.jpg
# 2022-01-04 02:16:00      27772 data_prep_workshop/pytorch/data/val/08/000000000671.jpg
# 2022-01-04 02:16:00      13886 data_prep_workshop/pytorch/data/val/08/000000041331.jpg
# 2022-01-04 02:16:01       9919 data_prep_workshop/pytorch/data/val/08/000000098107.jpg
# 2022-01-04 02:16:01      16992 data_prep_workshop/pytorch/data/val/08/000000106895.jpg
# 2022-01-04 02:16:01      18431 data_prep_workshop/pytorch/data/val/08/000000140529.jpg
# 2022-01-04 02:16:01      20155 data_prep_workshop/pytorch/data/val/08/000000140724.jpg
# 2022-01-04 02:16:00      11022 data_prep_workshop/pytorch/data/val/08/000000145288.jpg
# 2022-01-04 02:16:00      11666 data_prep_workshop/pytorch/data/val/08/000000147277.jpg
# 2022-01-04 02:16:01      19892 data_prep_workshop/pytorch/data/val/08/000000159338.jpg
# 2022-01-04 02:16:01      18529 data_prep_workshop/pytorch/data/val/08/000000160171.jpg
# 2022-01-04 02:16:01      14109 data_prep_workshop/pytorch/data/val/08/000000164698.jpg
# 2022-01-04 02:16:00      17780 data_prep_workshop/pytorch/data/val/08/000000170173.jpg
# 2022-01-04 02:16:01      21995 data_prep_workshop/pytorch/data/val/08/000000188478.jpg
# 2022-01-04 02:16:00       9148 data_prep_workshop/pytorch/data/val/08/000000206624.jpg
# 2022-01-04 02:16:00      12145 data_prep_workshop/pytorch/data/val/08/000000260276.jpg
# 2022-01-04 02:16:01      14735 data_prep_workshop/pytorch/data/val/08/000000281649.jpg
# 2022-01-04 02:16:01      21029 data_prep_workshop/pytorch/data/val/08/000000321831.jpg
# 2022-01-04 02:16:01      14683 data_prep_workshop/pytorch/data/val/08/000000327418.jpg
# 2022-01-04 02:16:00      18858 data_prep_workshop/pytorch/data/val/08/000000328163.jpg
# 2022-01-04 02:16:01      13410 data_prep_workshop/pytorch/data/val/08/000000338474.jpg
# 2022-01-04 02:16:00      13075 data_prep_workshop/pytorch/data/val/08/000000348904.jpg
# 2022-01-04 02:16:01      17016 data_prep_workshop/pytorch/data/val/08/000000352755.jpg
# 2022-01-04 02:16:01      15695 data_prep_workshop/pytorch/data/val/08/000000416911.jpg
# 2022-01-04 02:16:01      17215 data_prep_workshop/pytorch/data/val/08/000000426520.jpg
# 2022-01-04 02:16:01      11757 data_prep_workshop/pytorch/data/val/08/000000436078.jpg
# 2022-01-04 02:16:01      11827 data_prep_workshop/pytorch/data/val/08/000000469577.jpg
# 2022-01-04 02:16:00      19917 data_prep_workshop/pytorch/data/val/08/000000544933.jpg
# 2022-01-04 02:16:08      13423 data_prep_workshop/pytorch/data/val/09/000000071281.jpg
# 2022-01-04 02:16:09      13951 data_prep_workshop/pytorch/data/val/09/000000117965.jpg
# 2022-01-04 02:16:07      16026 data_prep_workshop/pytorch/data/val/09/000000148034.jpg
# 2022-01-04 02:16:09      15736 data_prep_workshop/pytorch/data/val/09/000000148181.jpg
# 2022-01-04 02:16:08      16357 data_prep_workshop/pytorch/data/val/09/000000179550.jpg
# 2022-01-04 02:16:08      19070 data_prep_workshop/pytorch/data/val/09/000000181934.jpg
# 2022-01-04 02:16:07      12293 data_prep_workshop/pytorch/data/val/09/000000187334.jpg
# 2022-01-04 02:16:08      18660 data_prep_workshop/pytorch/data/val/09/000000192894.jpg
# 2022-01-04 02:16:08      19708 data_prep_workshop/pytorch/data/val/09/000000199247.jpg
# 2022-01-04 02:16:08      15551 data_prep_workshop/pytorch/data/val/09/000000205505.jpg
# 2022-01-04 02:16:07      12186 data_prep_workshop/pytorch/data/val/09/000000222199.jpg
# 2022-01-04 02:16:09      19805 data_prep_workshop/pytorch/data/val/09/000000239861.jpg
# 2022-01-04 02:16:08      14693 data_prep_workshop/pytorch/data/val/09/000000242325.jpg
# 2022-01-04 02:16:08      21555 data_prep_workshop/pytorch/data/val/09/000000263428.jpg
# 2022-01-04 02:16:08      17123 data_prep_workshop/pytorch/data/val/09/000000269606.jpg
# 2022-01-04 02:16:08      21358 data_prep_workshop/pytorch/data/val/09/000000272162.jpg
# 2022-01-04 02:16:07      20040 data_prep_workshop/pytorch/data/val/09/000000281323.jpg
# 2022-01-04 02:16:08      11758 data_prep_workshop/pytorch/data/val/09/000000286770.jpg
# 2022-01-04 02:16:08      18322 data_prep_workshop/pytorch/data/val/09/000000287907.jpg
# 2022-01-04 02:16:07      18789 data_prep_workshop/pytorch/data/val/09/000000296573.jpg
# 2022-01-04 02:16:07      15085 data_prep_workshop/pytorch/data/val/09/000000304157.jpg
# 2022-01-04 02:16:08      15338 data_prep_workshop/pytorch/data/val/09/000000306711.jpg
# 2022-01-04 02:16:08      15776 data_prep_workshop/pytorch/data/val/09/000000315668.jpg
# 2022-01-04 02:16:08      11531 data_prep_workshop/pytorch/data/val/09/000000328917.jpg
# 2022-01-04 02:16:07      11738 data_prep_workshop/pytorch/data/val/09/000000334857.jpg
# 2022-01-04 02:16:08      14642 data_prep_workshop/pytorch/data/val/09/000000358983.jpg
# 2022-01-04 02:16:09      11243 data_prep_workshop/pytorch/data/val/09/000000391825.jpg
# 2022-01-04 02:16:08      13197 data_prep_workshop/pytorch/data/val/09/000000427137.jpg
# 2022-01-04 02:16:08      19099 data_prep_workshop/pytorch/data/val/09/000000430495.jpg
# 2022-01-04 02:16:08      16079 data_prep_workshop/pytorch/data/val/09/000000455476.jpg
# 2022-01-04 02:16:07      15240 data_prep_workshop/pytorch/data/val/09/000000456439.jpg
# 2022-01-04 02:16:08      17354 data_prep_workshop/pytorch/data/val/09/000000464800.jpg
# 2022-01-04 02:16:08      15836 data_prep_workshop/pytorch/data/val/09/000000507224.jpg
# 2022-01-04 02:16:08      13677 data_prep_workshop/pytorch/data/val/09/000000537150.jpg
# 2022-01-04 02:16:09      16279 data_prep_workshop/pytorch/data/val/09/000000538308.jpg
# 2022-01-04 02:16:08       8399 data_prep_workshop/pytorch/data/val/09/000000555687.jpg
# 2022-01-04 02:15:55      26632 data_prep_workshop/pytorch/data/val/10/000000062263.jpg
# 2022-01-04 02:15:56       9864 data_prep_workshop/pytorch/data/val/10/000000071526.jpg
# 2022-01-04 02:15:55      21259 data_prep_workshop/pytorch/data/val/10/000000092771.jpg
# 2022-01-04 02:15:55      17060 data_prep_workshop/pytorch/data/val/10/000000106079.jpg
# 2022-01-04 02:15:56      19050 data_prep_workshop/pytorch/data/val/10/000000141770.jpg
# 2022-01-04 02:15:56      17574 data_prep_workshop/pytorch/data/val/10/000000142686.jpg
# 2022-01-04 02:15:55      18326 data_prep_workshop/pytorch/data/val/10/000000169228.jpg
# 2022-01-04 02:15:54      20150 data_prep_workshop/pytorch/data/val/10/000000170327.jpg
# 2022-01-04 02:15:56      18087 data_prep_workshop/pytorch/data/val/10/000000178958.jpg
# 2022-01-04 02:15:55      20335 data_prep_workshop/pytorch/data/val/10/000000181697.jpg
# 2022-01-04 02:15:55      21543 data_prep_workshop/pytorch/data/val/10/000000192259.jpg
# 2022-01-04 02:15:55      11448 data_prep_workshop/pytorch/data/val/10/000000221055.jpg
# 2022-01-04 02:15:55      16828 data_prep_workshop/pytorch/data/val/10/000000229456.jpg
# 2022-01-04 02:15:56      17472 data_prep_workshop/pytorch/data/val/10/000000268185.jpg
# 2022-01-04 02:15:55      21709 data_prep_workshop/pytorch/data/val/10/000000276852.jpg
# 2022-01-04 02:15:55      22015 data_prep_workshop/pytorch/data/val/10/000000287890.jpg
# 2022-01-04 02:15:55      37780 data_prep_workshop/pytorch/data/val/10/000000298251.jpg
# 2022-01-04 02:15:55      18928 data_prep_workshop/pytorch/data/val/10/000000344483.jpg
# 2022-01-04 02:15:55      11041 data_prep_workshop/pytorch/data/val/10/000000372673.jpg
# 2022-01-04 02:15:56      19747 data_prep_workshop/pytorch/data/val/10/000000394974.jpg
# 2022-01-04 02:15:56      10647 data_prep_workshop/pytorch/data/val/10/000000428945.jpg
# 2022-01-04 02:15:55      22894 data_prep_workshop/pytorch/data/val/10/000000446383.jpg
# 2022-01-04 02:15:55      14867 data_prep_workshop/pytorch/data/val/10/000000454750.jpg
# 2022-01-04 02:15:55      18684 data_prep_workshop/pytorch/data/val/10/000000520422.jpg
# 2022-01-04 02:15:55      20653 data_prep_workshop/pytorch/data/val/10/000000527520.jpg
# 2022-01-04 02:15:56      18597 data_prep_workshop/pytorch/data/val/10/000000536412.jpg
# 2022-01-04 02:15:55      18068 data_prep_workshop/pytorch/data/val/10/000000551063.jpg
# 2022-01-04 02:15:55      22432 data_prep_workshop/pytorch/data/val/10/000000576327.jpg

# %% [markdown]
# <pre>
# </pre>

# %% [markdown]
# ## 다음 단계
# 훈련 및 검증 데이터 세트가 S3에 저장되었으므로 Pytorch 프레임워크용 SageMaker Estimator를 생성하고 원격 EC2 인스턴스에서 훈련 알고리즘을 실행할 수 있습니다.
