# %% [markdown]
# # [모듈 2.2] 고객 이탈 데이터 준비, Autogluon 훈련 및 평가

# %% [markdown]
# ### [알림] <font coler="red"> conda_python3 커널 </font> 과 함께 사용해야 합니다.
#
# * 이 노트북은 `0.1.Install_Package` 반드시 먼저 실행해야 합니다.

# %% [markdown]
# # 0. 환경 셋업

# %%
import pandas as pd
pd.set_option("display.max_columns", 500)

import numpy as np
import matplotlib.pyplot as plt
import os
import time
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(style="whitegrid")


import sagemaker
from sagemaker import get_execution_role

sess = sagemaker.Session()
bucket = sess.default_bucket()
prefix = "ml_data_prep_workshop/autogluon-bankfraud"
role = get_execution_role()

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # 1. 데이타 준비

# %%
fraud = pd.read_csv('data/PS_20174392719_1491204439457_log.csv')
fraud
# Out:
#          step      type      amount     nameOrig  oldbalanceOrg  \
# 0           1   PAYMENT     9839.64  C1231006815      170136.00
# 1           1   PAYMENT     1864.28  C1666544295       21249.00
# 2           1  TRANSFER      181.00  C1305486145         181.00
# 3           1  CASH_OUT      181.00   C840083671         181.00
# 4           1   PAYMENT    11668.14  C2048537720       41554.00
# ...       ...       ...         ...          ...            ...
# 6362615   743  CASH_OUT   339682.13   C786484425      339682.13
# 6362616   743  TRANSFER  6311409.28  C1529008245     6311409.28
# 6362617   743  CASH_OUT  6311409.28  C1162922333     6311409.28
# 6362618   743  TRANSFER   850002.52  C1685995037      850002.52
# 6362619   743  CASH_OUT   850002.52  C1280323807      850002.52
#
#          newbalanceOrig     nameDest  oldbalanceDest  newbalanceDest  isFraud  \
# 0             160296.36  M1979787155            0.00            0.00        0
# 1              19384.72  M2044282225            0.00            0.00        0
# 2                  0.00   C553264065            0.00            0.00        1
# 3                  0.00    C38997010        21182.00            0.00        1
# 4              29885.86  M1230701703            0.00            0.00        0
# ...                 ...          ...             ...             ...      ...
# 6362615            0.00   C776919290            0.00       339682.13        1
# 6362616            0.00  C1881841831            0.00            0.00        1
# 6362617            0.00  C1365125890        68488.84      6379898.11        1
# 6362618            0.00  C2080388513            0.00            0.00        1
# 6362619            0.00   C873221189      6510099.11      7360101.63        1
#
#          isFlaggedFraud
# 0                     0
# 1                     0
# 2                     0
# 3                     0
# 4                     0
# ...                 ...
# 6362615               0
# 6362616               0
# 6362617               0
# 6362618               0
# 6362619               0
#
# [6362620 rows x 11 columns]

# %% [markdown]
# ###  레이블 컬럼을 숫자형으로 변경 혹은 유지
#
# 레이블 컬럼이 숫자형으로 1, 0 이면 데이터 프레임의 가장 앞에 위치 시킴.
# 이유는 "상관 계수 분석시" 에 레이블 컬럼도 포함시기키 위함 입니다.

# %%
from src.tabular_utils import change_y

#    isChange 이면 레이블 컬럼을 데이터 프레임의 가장 맨 앞에 위치 함.
#    그렇지 않으면 'True.' --> 1 로 바꾸고, 아니면 0으로 합니다.
fraud = change_y(fraud, col='isFraud', isChange=False)
fraud
# Out:
#          isFraud  step      type      amount     nameOrig  oldbalanceOrg  \
# 0              0     1   PAYMENT     9839.64  C1231006815      170136.00
# 1              0     1   PAYMENT     1864.28  C1666544295       21249.00
# 2              1     1  TRANSFER      181.00  C1305486145         181.00
# 3              1     1  CASH_OUT      181.00   C840083671         181.00
# 4              0     1   PAYMENT    11668.14  C2048537720       41554.00
# ...          ...   ...       ...         ...          ...            ...
# 6362615        1   743  CASH_OUT   339682.13   C786484425      339682.13
# 6362616        1   743  TRANSFER  6311409.28  C1529008245     6311409.28
# 6362617        1   743  CASH_OUT  6311409.28  C1162922333     6311409.28
# 6362618        1   743  TRANSFER   850002.52  C1685995037      850002.52
# 6362619        1   743  CASH_OUT   850002.52  C1280323807      850002.52
#
#          newbalanceOrig     nameDest  oldbalanceDest  newbalanceDest  \
# 0             160296.36  M1979787155            0.00            0.00
# 1              19384.72  M2044282225            0.00            0.00
# 2                  0.00   C553264065            0.00            0.00
# 3                  0.00    C38997010        21182.00            0.00
# 4              29885.86  M1230701703            0.00            0.00
# ...                 ...          ...             ...             ...
# 6362615            0.00   C776919290            0.00       339682.13
# 6362616            0.00  C1881841831            0.00            0.00
# 6362617            0.00  C1365125890        68488.84      6379898.11
# 6362618            0.00  C2080388513            0.00            0.00
# 6362619            0.00   C873221189      6510099.11      7360101.63
#
#          isFlaggedFraud
# 0                     0
# 1                     0
# 2                     0
# 3                     0
# 4                     0
# ...                 ...
# 6362615               0
# 6362616               0
# 6362617               0
# 6362618               0
# 6362619               0
#
# [6362620 rows x 11 columns]

# %% [markdown]
# ## 피쳐 제거
# - "데이터 프로 파일링 분석" 과 "상관 계수 분석" 에 기반하여 아래 컬럼을 삭제 합니다.

# %%
drop_cols = ['step','isFlaggedFraud','nameOrig','nameDest']
fraud_cl = fraud.drop(columns=drop_cols)
fraud_cl
# Out:
#          isFraud      type      amount  oldbalanceOrg  newbalanceOrig  \
# 0              0   PAYMENT     9839.64      170136.00       160296.36
# 1              0   PAYMENT     1864.28       21249.00        19384.72
# 2              1  TRANSFER      181.00         181.00            0.00
# 3              1  CASH_OUT      181.00         181.00            0.00
# 4              0   PAYMENT    11668.14       41554.00        29885.86
# ...          ...       ...         ...            ...             ...
# 6362615        1  CASH_OUT   339682.13      339682.13            0.00
# 6362616        1  TRANSFER  6311409.28     6311409.28            0.00
# 6362617        1  CASH_OUT  6311409.28     6311409.28            0.00
# 6362618        1  TRANSFER   850002.52      850002.52            0.00
# 6362619        1  CASH_OUT   850002.52      850002.52            0.00
#
#          oldbalanceDest  newbalanceDest
# 0                  0.00            0.00
# 1                  0.00            0.00
# 2                  0.00            0.00
# 3              21182.00            0.00
# 4                  0.00            0.00
# ...                 ...             ...
# 6362615            0.00       339682.13
# 6362616            0.00            0.00
# 6362617        68488.84      6379898.11
# 6362618            0.00            0.00
# 6362619      6510099.11      7360101.63
#
# [6362620 rows x 7 columns]

# %% [markdown]
# # 3. 데이터 세트 분리
# - 전체 데이타를 8:1:1 의 비율로 훈련, 검증, 테스트 데이터 셋으로 분리 합니다.
# - 훈련과 검증 데이터는 CSV 데이터로 로컬에 저장 합니다.

# %%
train_data, validation_data, test_data = np.split(
    fraud_cl.sample(frac=1, random_state=1024),
    [int(0.8 * len(fraud_cl)), int(0.9 * len(fraud_cl))],
)
train_data.to_csv("train.csv", header=True, index=False)
validation_data.to_csv("validation.csv", header=True, index=False)

# %% [markdown]
# # Autogluon

# %%
train_df = train_data.copy()
val_df = validation_data.copy()
test_df = test_data.copy()

# %%
train_df.head()
# Out:
#          isFraud      type      amount  oldbalanceOrg  newbalanceOrig  \
# 185334         0   PAYMENT     1855.14            0.0            0.00
# 1267555        0   CASH_IN   183881.02        69630.0       253511.02
# 1974680        0  TRANSFER  2304730.15        59251.0            0.00
# 201403         0   PAYMENT     8271.71            0.0            0.00
# 5661861        0   CASH_IN    87252.58        11602.0        98854.58
#
#          oldbalanceDest  newbalanceDest
# 185334             0.00            0.00
# 1267555            0.00            0.00
# 1974680         5251.04      2309981.19
# 201403             0.00            0.00
# 5661861       732047.92       644795.35

# %% [markdown]
# ## 오토글루온 데이터 타입으로 변경

# %% [markdown]
# TBD

# %%
from autogluon.tabular import TabularPredictor as task
from autogluon.tabular import TabularDataset

# train_data = TabularDataset(auto_train_file)
train_data = TabularDataset(train_df)
val_data = TabularDataset(val_df)
test_data = TabularDataset(test_df)

# %%
import autogluon.core as ag

eval_metric = 'roc_auc' 

save_path = 'basic_fraud_autogluon_models'

presets = 'medium_quality_faster_train'
# presets = 'optimize_for_deployment'
label = 'isFraud'

tabular_predictor = task(label=label,
                         path = save_path,
                         eval_metric = eval_metric,
                        )

exclude_model_list = ['KNN','GBM','NN','FASTAI','RF','CAT','XT']
# exclude_model_list = ['KNN','NN','FASTAI','RF']
# Out:
# Warning: path already exists! This predictor may overwrite an existing predictor! path="basic_fraud_autogluon_models"

# %%
# %%time

predictor = tabular_predictor.fit(
                                   train_data = train_data, 
                                   tuning_data = val_data,    
                                   presets=presets,
                                   excluded_model_types= exclude_model_list    
                                   )
# Out:
# Presets specified: ['medium_quality_faster_train']
# Warning: Training may take a very long time because `time_limit` was not specified and `train_data` is large (5090096 samples, 612.96 MB).
# 	Consider setting `time_limit` to ensure training finishes within an expected duration or experiment with a small portion of `train_data` to identify an ideal `presets` and `hyperparameters` configuration.
# Beginning AutoGluon training ...
# AutoGluon will save models to "basic_fraud_autogluon_models/"
# AutoGluon Version:  0.3.1
# Train Data Rows:    5090096
# Train Data Columns: 6
# Tuning Data Rows:    636262
# Tuning Data Columns: 6
# Preprocessing data ...
# AutoGluon infers your prediction problem is: 'binary' (because only two unique label-values observed).
# 	2 unique label values:  [0, 1]
# 	If 'binary' is not the correct problem_type, please manually specify the problem_type argument in fit() (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# Selected class <--> label mapping:  class 1 = 1, class 0 = 0
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    237330.81 MB
# 	Train Data (Original)  Memory Usage: 597.96 MB (0.3% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 		Fitting CategoryFeatureGenerator...
# 			Fitting CategoryMemoryMinimizeFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', [])  : 5 | ['amount', 'oldbalanceOrg', 'newbalanceOrig', 'oldbalanceDest', 'newbalanceDest']
# 		('object', []) : 1 | ['type']
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('category', []) : 1 | ['type']
# 		('float', [])    : 5 | ['amount', 'oldbalanceOrg', 'newbalanceOrig', 'oldbalanceDest', 'newbalanceDest']
# 	20.0s = Fit runtime
# 	6 features in original data used to generate 6 features in processed data.
# 	Train Data (Processed) Memory Usage: 234.78 MB (0.1% of available memory)
# Data preprocessing and feature engineering runtime = 21.84s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'roc_auc'
# 	This metric expects predicted probabilities rather than predicted class labels, so you'll need to use predict_proba() instead of predict()
# 	To change this, specify the eval_metric argument of fit()
# Excluded Model Types: ['KNN', 'GBM', 'NN', 'FASTAI', 'RF', 'CAT', 'XT']
# 	Found 'NN' model in hyperparameters, but 'NN' is present in `excluded_model_types` and will be removed.
# 	Found 'GBM' model in hyperparameters, but 'GBM' is present in `excluded_model_types` and will be removed.
# 	Found 'GBM' model in hyperparameters, but 'GBM' is present in `excluded_model_types` and will be removed.
# 	Found 'GBM' model in hyperparameters, but 'GBM' is present in `excluded_model_types` and will be removed.
# 	Found 'CAT' model in hyperparameters, but 'CAT' is present in `excluded_model_types` and will be removed.
# 	Found 'FASTAI' model in hyperparameters, but 'FASTAI' is present in `excluded_model_types` and will be removed.
# 	Found 'RF' model in hyperparameters, but 'RF' is present in `excluded_model_types` and will be removed.
# 	Found 'RF' model in hyperparameters, but 'RF' is present in `excluded_model_types` and will be removed.
# 	Found 'RF' model in hyperparameters, but 'RF' is present in `excluded_model_types` and will be removed.
# 	Found 'XT' model in hyperparameters, but 'XT' is present in `excluded_model_types` and will be removed.
# 	Found 'XT' model in hyperparameters, but 'XT' is present in `excluded_model_types` and will be removed.
# 	Found 'XT' model in hyperparameters, but 'XT' is present in `excluded_model_types` and will be removed.
# 	Found 'KNN' model in hyperparameters, but 'KNN' is present in `excluded_model_types` and will be removed.
# 	Found 'KNN' model in hyperparameters, but 'KNN' is present in `excluded_model_types` and will be removed.
# Fitting 1 L1 models ...
# Fitting model: XGBoost ...
# 	0.9999	 = Validation score   (roc_auc)
# 	42.88s	 = Training   runtime
# 	1.95s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ...
# 	0.9999	 = Validation score   (roc_auc)
# 	0.19s	 = Training   runtime
# 	0.18s	 = Validation runtime
# AutoGluon training complete, total runtime = 70.39s ...
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("basic_fraud_autogluon_models/")
# CPU times: user 11min 6s, sys: 7.05 s, total: 11min 13s
# Wall time: 1min 10s

# %% [markdown]
# ## 모델 예측

# %%
y_test = test_data[label]  # values to predict
test_data_nolab = test_data.drop(labels=[label],axis=1)  # delete label column to prove we're not cheating

# %%
# predictor = task.load(dir)  # unnecessary, just demonstrates how to load previously-trained predictor from file

prediction = predictor.predict(test_data_nolab)
prediction_prob = predictor.predict_proba(test_data_nolab)
# print("Predictions:  ", prediction)
# perf = predictor.evaluate_predictions(y_true=y_test, y_pred=prediction, auxiliary_metrics=True)
perf = predictor.evaluate_predictions(y_true=y_test, y_pred=prediction_prob, auxiliary_metrics=True)
# Out:
# Evaluation: roc_auc on test data: 0.9997979435687551
# Evaluations on test data:
# {
#     "roc_auc": 0.9997979435687551,
#     "accuracy": 0.9996730906450487,
#     "balanced_accuracy": 0.8884538049734524,
#     "mcc": 0.8622507041484996,
#     "f1": 0.8577291381668946,
#     "precision": 0.9572519083969465,
#     "recall": 0.7769516728624535
# }

# %%
from src.tabular_utils import get_prediction_set, compute_f1

threshold = 500
df_pred = get_prediction_set(prediction, prediction_prob, threshold )    
df_pred
# Out:
#          score  pred
# 4859644      0     0
# 2524773      0     0
# 3149940      0     0
# 5920777      0     0
# 1981300      0     0
# ...        ...   ...
# 4063833      0     0
# 5261925      0     0
# 3521121      0     0
# 4924305      0     0
# 5183419      0     0
#
# [636262 rows x 2 columns]

# %%
from sklearn.metrics import classification_report, roc_auc_score
from IPython.display import display as dp
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
#from src import p_utils
# %matplotlib inline
# %config InlineBackend.figure_format='retina'



compute_f1(y_test, df_pred.pred.values)
# Out:
# - ROC_AUC SCORE
# 	-0.888
#
# - F1 SCORE
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    635455
#            1       0.96      0.78      0.86       807
#
#     accuracy                           1.00    636262
#    macro avg       0.98      0.89      0.93    636262
# weighted avg       1.00      1.00      1.00    636262
#
# [[635427     28]
#  [   180    627]]

# %% [markdown]
# ## 리더 보드 생성

# %%
 predictor.leaderboard(test_data,  extra_info=False, silent=True)
# Out:
#                  model  score_test  score_val  pred_time_test  pred_time_val  \
# 0              XGBoost    0.999798    0.99991        1.540726       1.952909
# 1  WeightedEnsemble_L2    0.999798    0.99991        1.546977       2.137329
#
#     fit_time  pred_time_test_marginal  pred_time_val_marginal  \
# 0  42.876859                 1.540726                1.952909
# 1  43.069138                 0.006250                0.184420
#
#    fit_time_marginal  stack_level  can_infer  fit_order
# 0          42.876859            1       True          1
# 1           0.192279            2       True          2

# %% [markdown]
# ## Feature Importance

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(style="whitegrid")

fea_importance_raw = predictor.feature_importance(test_data)

fea_importance = fea_importance_raw['importance']

f, ax = plt.subplots(figsize=(10,5))
plot = sns.barplot(x=fea_importance.index, y = fea_importance.values)

ax.set_title('Feature Importance')
plot.set_xticklabels(plot.get_xticklabels(),rotation='vertical')
plt.show()
# Out:
# Computing feature importance via permutation shuffling for 6 features using 1000 rows with 3 shuffle sets...
# 	1.49s	= Expected runtime (0.5s per shuffle set)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-7fade3df7376> in <module>
#       3 sns.set(style="whitegrid")
#       4
# ----> 5 fea_importance_raw = predictor.feature_importance(test_data)
#       6
#       7 fea_importance = fea_importance_raw['importance']
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/autogluon/tabular/predictor/predictor.py in feature_importance(self, data, model, features, feature_stage, subsample_size, time_limit, num_shuffle_sets, include_confidence_band, silent)
#    1454
#    1455         fi_df = self._learner.get_feature_importance(model=model, X=data, features=features, feature_stage=feature_stage,
# -> 1456                                                      subsample_size=subsample_size, time_limit=time_limit, num_shuffle_sets=num_shuffle_sets, silent=silent)
#    1457
#    1458         if include_confidence_band:
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/autogluon/tabular/learner/abstract_learner.py in get_feature_importance(self, model, X, y, features, feature_stage, subsample_size, silent, **kwargs)
#     681
#     682             if feature_stage == 'original':
# --> 683                 return trainer._get_feature_importance_raw(model=model, X=X, y=y, features=features, subsample_size=subsample_size, transform_func=self.transform_features, silent=silent, **kwargs)
#     684             X = self.transform_features(X)
#     685         else:
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/autogluon/tabular/trainer/abstract_trainer.py in _get_feature_importance_raw(self, X, y, model, eval_metric, **kwargs)
#    1506         predict_func_kwargs = dict(model=model)
#    1507         return compute_permutation_feature_importance(
# -> 1508             X=X, y=y, predict_func=predict_func, predict_func_kwargs=predict_func_kwargs, eval_metric=eval_metric, **kwargs
#    1509         )
#    1510
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/autogluon/core/utils/utils.py in compute_permutation_feature_importance(X, y, predict_func, eval_metric, features, subsample_size, num_shuffle_sets, predict_func_kwargs, transform_func, transform_func_kwargs, time_limit, silent, log_prefix, importance_as_list)
#     727             X_transformed = X if transform_func is None else transform_func(X, **transform_func_kwargs)
#     728             y_pred = predict_func(X_transformed, **predict_func_kwargs)
# --> 729             score_baseline = eval_metric(y, y_pred)
#     730             if shuffle_repeat == 0:
#     731                 if not silent:
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/autogluon/core/metrics/__init__.py in __call__(self, y_true, y_pred, sample_weight)
#     229                                                  **self._kwargs)
#     230         else:
# --> 231             return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#     232
#     233     @property
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/sklearn/metrics/_ranking.py in roc_auc_score(y_true, y_score, average, sample_weight, max_fpr, multi_class, labels)
#     543                                              max_fpr=max_fpr),
#     544                                      y_true, y_score, average,
# --> 545                                      sample_weight=sample_weight)
#     546     else:  # multilabel-indicator
#     547         return _average_binary_score(partial(_binary_roc_auc_score,
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/sklearn/metrics/_base.py in _average_binary_score(binary_metric, y_true, y_score, average, sample_weight)
#      75
#      76     if y_type == "binary":
# ---> 77         return binary_metric(y_true, y_score, sample_weight=sample_weight)
#      78
#      79     check_consistent_length(y_true, y_score, sample_weight)
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/sklearn/metrics/_ranking.py in _binary_roc_auc_score(y_true, y_score, sample_weight, max_fpr)
#     325     """Binary roc auc score."""
#     326     if len(np.unique(y_true)) != 2:
# --> 327         raise ValueError("Only one class present in y_true. ROC AUC score "
#     328                          "is not defined in that case.")
#     329
#
# ValueError: Only one class present in y_true. ROC AUC score is not defined in that case.

# %%
# fea_importance_raw

# %%
test_data.isFraud.value_counts()
# Out:
# 0    635455
# 1       807
# Name: isFraud, dtype: int64
